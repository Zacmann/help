# %%
spacy.lang.en.stop_words

# %%
import pandas as pd
import numpy as np
import spacy
import gensim
import pyLDAvis.gensim_models
from spacy.lang.en.stop_words import STOP_WORDS
from spacy import displacy
from spacy.matcher import Matcher
from textblob import TextBlob
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nlp=spacy.blank('en')

# %%
doc1=nlp('''ioneer Building, San Francisco, headquarters of OpenAI

Sam Altman, CEO of OpenAI ChatGPT was fine-tuned on top of GPT-3.5 using supervised learning as well as reinforcement learning.[5] Both approaches used human trainers to improve the model's performance. In the case of supervised learning, the model was provided with conversations in which the trainers played both sides: the user and the AI assistant. In the reinforcement step, human trainers first ranked responses that the model had created in a previous conversation. These rankings were used to create 'reward models' that the model was further fine-tuned on using several iterations of Proximal Policy Optimization (PPO).[6][7] Proximal Policy Optimization algorithms present a cost-effective benefit to trust region policy optimization algorithms; they negate many of the computationally expensive operations with faster performance.[8][9] The models were trained in collaboration with Microsoft on their Azure supercomputing infrastructure.

In addition, OpenAI continues to gather data from ChatGPT users that could be used to further train and fine-tune ChatGPT. Users are allowed to upvote or downvote the responses they receive from ChatGPT; upon upvoting or downvoting, they can also fill out a text field with additional feedback.[10][11][12]

Features and limitations

Cropped screenshot of a conversation with ChatGPT, December 30, 2022 Although the core function of a chatbot is to mimic a human conversationalist, ChatGPT is versatile. For example, it has the ability to write and debug computer programs; to compose music, teleplays, fairy tales, and student essays; to answer test questions (sometimes, depending on the test, at a level above the average human test-taker);[13] to write poetry and song lyrics;[14] to emulate a Linux system; to simulate an entire chat room; to play games like tic-tac-toe; and to simulate an ATM.[15] ChatGPT's training data includes man pages and information about Internet phenomena and programming languages, such as bulletin board systems and the Python programming language.[15]

In comparison to its predecessor, InstructGPT, ChatGPT attempts to reduce harmful and deceitful responses.[16] In one example, whereas InstructGPT accepts the premise of the prompt "Tell me about when Christopher Columbus came to the US in 2015" as being truthful, ChatGPT acknowledges the counterfactual nature of the question and frames its answer as a hypothetical consideration of what might happen if Columbus came to the U.S. in 2015, using information about Columbus' voyages and facts about the modern world – including modern perceptions of Columbus' actions.[6]

Unlike most chatbots, ChatGPT remembers previous prompts given to it in the same conversation; journalists have suggested that this will allow ChatGPT to be used as a personalized therapist.[17] To prevent offensive outputs from being presented to and produced from ChatGPT, queries are filtered through OpenAI's company-wide moderation API,[18][19] and potentially racist or sexist prompts are dismissed.[6][17]

ChatGPT suffers from multiple limitations. OpenAI acknowledged that ChatGPT "sometimes writes plausible-sounding but incorrect or nonsensical answers".[6] This behavior is common to large language models and is called hallucination.[20] The reward model of ChatGPT, designed around human oversight, can be over-optimized and thus hinder performance, otherwise known as Goodhart's law.[21] ChatGPT has limited knowledge of events that occurred after 2021. According to the BBC, as of December 2022 ChatGPT is not allowed to "express political opinions or engage in political activism".[22] Yet, research suggests that ChatGPT exhibits a pro-environmental, left-libertarian orientation when prompted to take a stance on political statements from two established voting advice applications.[23] In training ChatGPT, human reviewers preferred longer answers, irrespective of actual comprehension or factual content.[6] Training data also suffers from algorithmic bias, which may be revealed when ChatGPT responds to prompts including descriptors of people. In one instance, ChatGPT generated a rap indicating that women and scientists of color were inferior to white and male scientists.[24][25]

Service ChatGPT was launched on November 30, 2022, by San Francisco-based OpenAI, the creator of DALL·E 2 and Whisper. The service was launched as initially free to the public, with plans to monetize the service later.[26] By December 4, OpenAI estimated ChatGPT already had over one million users.[10] CNBC wrote on December 15, 2022, that the service "still goes down from time to time".[27] The service works best in English, but is also able to function in some other languages, to varying degrees of success.[14] Unlike some other recent high-profile advances in AI, as of December 2022, there is no sign of an official peer-reviewed technical paper about ChatGPT.[28]

According to OpenAI guest researcher Scott Aaronson, OpenAI is working on a tool to attempt to watermark its text generation systems so as to combat bad actors using their services for academic plagiarism or for spam.[29][30] The New York Times relayed in December 2022 that the next version of GPT, GPT-4, has been "rumored" to be launched sometime in 2023.[17]

Reception and implications Positive reactions ChatGPT was met in December 2022 with generally positive reviews; The New York Times labeled it "the best artificial intelligence chatbot ever released to the general public".[31] Samantha Lock of The Guardian noted that it was able to generate "impressively detailed" and "human-like" text.[32] Technology writer Dan Gillmor used ChatGPT on a student assignment, and found its generated text was on par with what a good student would deliver and opined that "academia has some very serious issues to confront".[33] Alex Kantrowitz of Slate magazine lauded ChatGPT's pushback to questions related to Nazi Germany, including the claim that Adolf Hitler built highways in Germany, which was met with information regarding Nazi Germany's use of forced labor.[34]

In The Atlantic's "Breakthroughs of the Year" for 2022, Derek Thompson included ChatGPT as part of "the generative-AI eruption" that "may change our mind about how we work, how we think, and what human creativity really is".[35]

Kelsey Piper of the Vox website wrote that "ChatGPT is the general public's first hands-on introduction to how powerful modern AI has gotten, and as a result, many of us are [stunned]" and that ChatGPT is "smart enough to be useful despite its flaws".[36] Paul Graham of Y Combinator tweeted that "The striking thing about the reaction to ChatGPT is not just the number of people who are blown away by it, but who they are. These are not people who get excited by every shiny new thing. Clearly, something big is happening."[37] Elon Musk wrote that "ChatGPT is scary good. We are not far from dangerously strong AI".[36] Musk paused OpenAI's access to a Twitter database pending a better understanding of OpenAI's plans, stating that "OpenAI was started as open-source and non-profit. Neither is still true."[38][39] Musk had co-founded OpenAI in 2015, in part to address existential risk from artificial intelligence, but had resigned in 2018.[39]

Google CEO Sundar Pichai upended the work of numerous internal groups in response to the threat of disruption by ChatGPT.[40] In December 2022, Google internally expressed alarm at the unexpected strength of ChatGPT and the newly discovered potential of large language models to disrupt the search engine business, and CEO Sundar Pichai "upended" and reassigned teams within multiple departments to aid in its artificial intelligence products, according to The New York Times.[40] The Information reported on January 3, 2023 that Microsoft Bing was planning to add optional ChatGPT functionality into its public search engine, possibly around March 2023.[41][42]

Stuart Cobbe, a chartered accountant in England & Wales, decided to the test the ChatGPT chatbot by entering questions from a sample exam paper on the ICAEW website and then entering its answers back into the online test. ChatGPT scored 42% which, while below the 55% pass mark, was considered a reasonable attempt.''')

# %%
count=0
for token in doc1:
    count=count+1
print(count)
# Out:
# 1489

# %%
doc1[10]
# Out:
# Sam

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
nlp=spacy.load('en_core_web_sm')

# %%
t_count=0
for token in doc1:
    t_count=t_count+1
print(' The no of tokens:',t_count)

s_count=0
for token in doc1:
    if token.is_stop == False:
        s_count=s_count+1
print('\n The no of non-stop words:',s_count,'-----token.is_stop')

p_count=0
for token in doc1:
    if token.is_punct == False:
        p_count=p_count+1
print('\n The no of non-punctuations:',p_count,'-----token.is_punct')

lp_count=0
for token in doc1:
    if token.is_left_punct == True:
        lp_count=lp_count+1
print('\n The no of left punctuations:',lp_count, '-----token.is_left_punct')

rp_count=0
for token in doc1:
    if token.is_right_punct == True:
        rp_count=rp_count+1
print('\n The no of right punctuations:',rp_count,'-----token.is_right_punct')


a_count=0
for token in doc1:
    if token.is_alpha == True:
        a_count=a_count+1
print('\n The no of alphabets:',a_count,'-----token.is_alpha')


d_count=0
for token in doc1:
    if token.is_digit == True:
        d_count=d_count+1
print('\n The no of digits:',d_count,'-----token.is_digit')

n_count=0
for token in doc1:
    if token.like_num == True:
        n_count=n_count+1
print('\n The count of like numbers:',n_count,'-----token.like_num')



l_count=0
for token in doc1:
    if token.is_lower == True:
        l_count=l_count+1
print('\n The no of lower case tokens:',l_count,'-----token.is_lower')


u_count=0
for token in doc1:
    if token.is_upper == True:
        u_count=u_count+1
print('\n The no of upper case tokens:',u_count,'-----token.is_upper')


t_count=0
for token in doc1:
    if token.is_title == True:
        t_count=t_count+1
print('\n The no of title cases:',t_count,'-----token.is_title')

q_count=0
for token in doc1:
    if token.is_quote == True:
        q_count=q_count+1
print('\n The no of quotes:',q_count,'-----token.is_quote')



URL_count=0
for token in doc1:
    if token.like_url==True :
        URL_count=URLcount+1
print('\n The count of URLs' , URL_count,'------token.like_url')
    
e_count=0 
for token in doc1:
    if token.like_email==True:
        e_count=e_count+1
print('\n The count of Emails', e_count,'-----token.like_email')


print('\n print(token.text,   , token.pos_)')
print('\n  print(token.text,,token.tag_)')

print('\n pos_count=doc1.count_by(spacy.attrs.POS)')

sent_count=0
for sent in doc1.sents:
    sent_count=sent_count+1
print('\nsent count is','--',sent_count,'-----doc1.sent')

print('\n print(token.text,,token.dep_)')

print('\n print(token.text,,token.head)')    

print('\n for chunk in doc1.noun_chunks: print(chunk.text, ,chunk.label_')
# Out:
#  The no of tokens: 1489
#
#  The no of non-stop words: 948 -----token.is_stop
#
#  The no of non-punctuations: 1292 -----token.is_punct
#
#  The no of left punctuations: 33 -----token.is_left_punct
#
#  The no of right punctuations: 71 -----token.is_right_punct
#
#  The no of alphabets: 1202 -----token.is_alpha
#
#  The no of digits: 22 -----token.is_digit
#
#  The count of like numbers: 29 -----token.like_num
#
#  The no of lower case tokens: 1041 -----token.is_lower
#
#  The no of upper case tokens: 21 -----token.is_upper
#
#  The no of title cases: 139 -----token.is_title
#
#  The no of quotes: 30 -----token.is_quote
#
#  The count of URLs 0 ------token.like_url
#
#  The count of Emails 0 -----token.like_email
#
#  print(token.text,   , token.pos_)
#
#   print(token.text,,token.tag_)
#
#  pos_count=doc1.count_by(spacy.attrs.POS)
#
# sent count is -- 33 -----doc1.sent
#
#  print(token.text,,token.dep_)
#
#  print(token.text,,token.head)
#
#  for chunk in doc1.noun_chunks: print(chunk.text, ,chunk.label_

# %%
#LIST 

text_2=['Today is Monday','Tomorrow is Tuesday',
       'Yesterday was a holiday']

# Tokens

for sentence in nlp.pipe(text_2):
    print(sentence)
    for token in sentence:
        print(len(token))
# Out:
# Today is Monday
# 5
# 2
# 6
# Tomorrow is Tuesday
# 8
# 2
# 7
# Yesterday was a holiday
# 9
# 3
# 1
# 7

# %%
#TUPLE

text_3=('Today is Monday','Tomorrow is Tuesday',
       'Yesterday was Sundaya,a holiday')

for sent in nlp.pipe(text_3):
    print(sent)
    for token in sent:
        print(len(token))
# Out:
# Today is Monday
# 5
# 2
# 6
# Tomorrow is Tuesday
# 8
# 2
# 7
# Yesterday was Sundaya,a holiday
# 9
# 3
# 7
# 1
# 1
# 7

# %%
text_4=[('Today is Monday'),('Tomorrow is Tuesday'),
       ('Yesterday was Sundaya,a holiday')]


sent_count=0
for sent in nlp.pipe(text_4):
    sent_count=sent_count+1
    print(sent_count,'=>',sent)
    for token in sent:
        print(token)
# Out:
# 1 => Today is Monday
# Today
# is
# Monday
# 2 => Tomorrow is Tuesday
# Tomorrow
# is
# Tuesday
# 3 => Yesterday was Sundaya,a holiday
# Yesterday
# was
# Sundaya
# ,
# a
# holiday

# %%
text_df=pd.DataFrame(text_2,columns=['Sentence'])
text_df
# Out:
#                   Sentence
# 0          Today is Monday
# 1      Tomorrow is Tuesday
# 2  Yesterday was a holiday

# %%
# nlp.pipe(text_df['Sentence'])#

for sent in nlp.pipe(text_df['Sentence']):
    print(sent)
    for token in sent:
        print(token)
# Out:
# Today is Monday
# Today
# is
# Monday
# Tomorrow is Tuesday
# Tomorrow
# is
# Tuesday
# Yesterday was a holiday
# Yesterday
# was
# a
# holiday

# %%
## Separating doc into sentences
X=[]
for sent in doc1.sents:
    print(sent)
    X.append(sent.text)
# Out:
# ioneer Building, San Francisco, headquarters of OpenAI
#
# Sam Altman, CEO of OpenAI ChatGPT was fine-tuned on top of GPT-3.5 using supervised learning as well as reinforcement learning.[5] Both approaches used human trainers to improve the model's performance.
# In the case of supervised learning, the model was provided with conversations in which the trainers played both sides: the user and the AI assistant.
# In the reinforcement step, human trainers first ranked responses that the model had created in a previous conversation.
# These rankings were used to create 'reward models' that the model was further fine-tuned on using several iterations of Proximal Policy Optimization (PPO).[6][7] Proximal Policy Optimization algorithms present a cost-effective benefit to trust region policy optimization algorithms; they negate many of the computationally expensive operations with faster performance.[8][9]
# The models were trained in collaboration with Microsoft on their Azure supercomputing infrastructure.
#
#
# In addition, OpenAI continues to gather data from ChatGPT users that could be used to further train and fine-tune ChatGPT.
# Users are allowed to upvote or downvote the responses they receive from ChatGPT; upon upvoting or downvoting, they can also fill out a text field with additional feedback.[10][11][12]
#
# Features and limitations
#
# Cropped screenshot of a conversation with ChatGPT, December 30, 2022 Although the core function of a chatbot is to mimic a human conversationalist, ChatGPT is versatile.
# For example, it has the ability to write and debug computer programs; to compose music, teleplays, fairy tales, and student essays; to answer test questions (sometimes, depending on the test, at a level above the average human test-taker);[13] to write poetry and song lyrics;[14] to emulate a Linux system; to simulate an entire chat room; to play games like tic-tac-toe; and to simulate an ATM.[15] ChatGPT's training data includes man pages and information about Internet phenomena and programming languages, such as bulletin board systems and the Python programming language.[15]
#
# In comparison to its predecessor, InstructGPT, ChatGPT attempts to reduce harmful and deceitful responses.[16]
# In one example, whereas InstructGPT accepts the premise of the prompt "Tell me about when Christopher Columbus came to the US in 2015" as being truthful, ChatGPT acknowledges the counterfactual nature of the question and frames its answer as a hypothetical consideration of what might happen if Columbus came to the U.S. in 2015, using information about Columbus' voyages and facts about the modern world – including modern perceptions of Columbus' actions.[6]
#
# Unlike most chatbots, ChatGPT remembers previous prompts given to it in the same conversation; journalists have suggested that this will allow ChatGPT to be used as a personalized therapist.[17] To prevent offensive outputs from being presented to and produced from ChatGPT, queries are filtered through OpenAI's company-wide moderation API,[18][19] and potentially racist or sexist prompts are dismissed.[6][17]
#
# ChatGPT suffers from multiple limitations.
# OpenAI acknowledged that ChatGPT "sometimes writes plausible-sounding but incorrect or nonsensical answers".[6]
# This behavior is common to large language models and is called hallucination.[20] The reward model of ChatGPT, designed around human oversight, can be over-optimized and thus hinder performance, otherwise known as Goodhart's law.[21] ChatGPT has limited knowledge of events that occurred after 2021.
# According to the BBC, as of December 2022 ChatGPT is not allowed to "express political opinions or engage in political activism".[22] Yet, research suggests that ChatGPT exhibits a pro-environmental, left-libertarian orientation when prompted to take a stance on political statements from two established voting advice applications.[23]
# In training ChatGPT, human reviewers preferred longer answers, irrespective of actual comprehension or factual content.[6]
# Training data also suffers from algorithmic bias, which may be revealed when ChatGPT responds to prompts including descriptors of people.
# In one instance, ChatGPT generated a rap indicating that women and scientists of color were inferior to white and male scientists.[24][25]
#
# Service ChatGPT was launched on November 30, 2022, by San Francisco-based OpenAI, the creator of DALL·E 2 and Whisper.
# The service was launched as initially free to the public, with plans to monetize the service later.[26] By December 4, OpenAI estimated ChatGPT already had over one million users.[10] CNBC wrote on December 15, 2022, that the service "still goes down from time to time".[27]
# The service works best in English, but is also able to function in some other languages, to varying degrees of success.[14]
# Unlike some other recent high-profile advances in AI, as of December 2022, there is no sign of an official peer-reviewed technical paper about ChatGPT.[28]
#
#
# According to OpenAI guest researcher Scott Aaronson, OpenAI is working on a tool to attempt to watermark its text generation systems so as to combat bad actors using their services for academic plagiarism or for spam.[29][30]
# The New York Times relayed in December 2022 that the next version of GPT, GPT-4, has been "rumored" to be launched sometime in 2023.[17]
#
#
# Reception and implications Positive reactions ChatGPT was met in December 2022 with generally positive reviews; The New York Times labeled it "the best artificial intelligence chatbot ever released to the general public".[31] Samantha Lock of The Guardian noted that it was able to generate "impressively detailed" and "human-like" text.[32] Technology writer Dan Gillmor used ChatGPT on a student assignment, and found its generated text was on par with what a good student would deliver and opined that "academia has some very serious issues to confront".[33] Alex Kantrowitz of Slate magazine lauded ChatGPT's pushback to questions related to Nazi Germany, including the claim that Adolf Hitler built highways in Germany, which was met with information regarding Nazi Germany's use of forced labor.[34]
#
#
# In The Atlantic's "Breakthroughs of the Year" for 2022, Derek Thompson included ChatGPT as part of "the generative-AI eruption" that "may change our mind about how we work, how we think, and what human creativity really is".[35]
#
# Kelsey Piper of the Vox website wrote that "ChatGPT is the general public's first hands-on introduction to how powerful modern AI has gotten, and as a result, many of us are
# [stunned]" and that ChatGPT is "smart enough to be useful despite its flaws".[36] Paul Graham of Y Combinator tweeted that "The striking thing about the reaction to ChatGPT is not just the number of people who are blown away by it, but who they are.
# These are not people who get excited by every shiny new thing.
# Clearly, something big is happening.
# "[37] Elon Musk wrote that "ChatGPT is scary good.
# We are not far from dangerously strong AI".[36] Musk paused OpenAI's access to a Twitter database pending a better understanding of OpenAI's plans, stating that "OpenAI was started as open-source and non-profit.
# Neither is still true.
# "[38][39] Musk had co-founded OpenAI in 2015, in part to address existential risk from artificial intelligence, but had resigned in 2018.[39]
#
#
# Google CEO Sundar Pichai upended the work of numerous internal groups in response to the threat of disruption by ChatGPT.[40]
# In December 2022, Google internally expressed alarm at the unexpected strength of ChatGPT and the newly discovered potential of large language models to disrupt the search engine business, and CEO Sundar Pichai "upended" and reassigned teams within multiple departments to aid in its artificial intelligence products, according to The New York Times.[40]
# The Information reported on January 3, 2023 that Microsoft Bing was planning to add optional ChatGPT functionality into its public search engine, possibly around March 2023.[41][42]
#
# Stuart Cobbe, a chartered accountant in England & Wales, decided to the test the ChatGPT chatbot by entering questions from a sample exam paper on the ICAEW website and then entering its answers back into the online test.
# ChatGPT scored 42% which, while below the 55% pass mark, was considered a reasonable attempt.

# %%
X
# Out:
# [ioneer Building, San Francisco, headquarters of OpenAI
#
#  Sam Altman, CEO of OpenAI ChatGPT was fine-tuned on top of GPT-3.5 using supervised learning as well as reinforcement learning.[5] Both approaches used human trainers to improve the model's performance.,
#  In the case of supervised learning, the model was provided with conversations in which the trainers played both sides: the user and the AI assistant.,
#  In the reinforcement step, human trainers first ranked responses that the model had created in a previous conversation.,
#  These rankings were used to create 'reward models' that the model was further fine-tuned on using several iterations of Proximal Policy Optimization (PPO).[6][7] Proximal Policy Optimization algorithms present a cost-effective benefit to trust region policy optimization algorithms; they negate many of the computationally expensive operations with faster performance.[8][9],
#  The models were trained in collaboration with Microsoft on their Azure supercomputing infrastructure.
#  ,
#  In addition, OpenAI continues to gather data from ChatGPT users that could be used to further train and fine-tune ChatGPT.,
#  Users are allowed to upvote or downvote the responses they receive from ChatGPT; upon upvoting or downvoting, they can also fill out a text field with additional feedback.[10][11][12]
#
#  Features and limitations
#
#  Cropped screenshot of a conversation with ChatGPT, December 30, 2022 Although the core function of a chatbot is to mimic a human conversationalist, ChatGPT is versatile.,
#  For example, it has the ability to write and debug computer programs; to compose music, teleplays, fairy tales, and student essays; to answer test questions (sometimes, depending on the test, at a level above the average human test-taker);[13] to write poetry and song lyrics;[14] to emulate a Linux system; to simulate an entire chat room; to play games like tic-tac-toe; and to simulate an ATM.[15] ChatGPT's training data includes man pages and information about Internet phenomena and programming languages, such as bulletin board systems and the Python programming language.[15]
#
#  In comparison to its predecessor, InstructGPT, ChatGPT attempts to reduce harmful and deceitful responses.[16],
#  In one example, whereas InstructGPT accepts the premise of the prompt "Tell me about when Christopher Columbus came to the US in 2015" as being truthful, ChatGPT acknowledges the counterfactual nature of the question and frames its answer as a hypothetical consideration of what might happen if Columbus came to the U.S. in 2015, using information about Columbus' voyages and facts about the modern world – including modern perceptions of Columbus' actions.[6]
#
#  Unlike most chatbots, ChatGPT remembers previous prompts given to it in the same conversation; journalists have suggested that this will allow ChatGPT to be used as a personalized therapist.[17] To prevent offensive outputs from being presented to and produced from ChatGPT, queries are filtered through OpenAI's company-wide moderation API,[18][19] and potentially racist or sexist prompts are dismissed.[6][17]
#
#  ChatGPT suffers from multiple limitations.,
#  OpenAI acknowledged that ChatGPT "sometimes writes plausible-sounding but incorrect or nonsensical answers".[6],
#  This behavior is common to large language models and is called hallucination.[20] The reward model of ChatGPT, designed around human oversight, can be over-optimized and thus hinder performance, otherwise known as Goodhart's law.[21] ChatGPT has limited knowledge of events that occurred after 2021.,
#  According to the BBC, as of December 2022 ChatGPT is not allowed to "express political opinions or engage in political activism".[22] Yet, research suggests that ChatGPT exhibits a pro-environmental, left-libertarian orientation when prompted to take a stance on political statements from two established voting advice applications.[23],
#  In training ChatGPT, human reviewers preferred longer answers, irrespective of actual comprehension or factual content.[6],
#  Training data also suffers from algorithmic bias, which may be revealed when ChatGPT responds to prompts including descriptors of people.,
#  In one instance, ChatGPT generated a rap indicating that women and scientists of color were inferior to white and male scientists.[24][25]
#
#  Service ChatGPT was launched on November 30, 2022, by San Francisco-based OpenAI, the creator of DALL·E 2 and Whisper.,
#  The service was launched as initially free to the public, with plans to monetize the service later.[26] By December 4, OpenAI estimated ChatGPT already had over one million users.[10] CNBC wrote on December 15, 2022, that the service "still goes down from time to time".[27],
#  The service works best in English, but is also able to function in some other languages, to varying degrees of success.[14],
#  Unlike some other recent high-profile advances in AI, as of December 2022, there is no sign of an official peer-reviewed technical paper about ChatGPT.[28]
#  ,
#  According to OpenAI guest researcher Scott Aaronson, OpenAI is working on a tool to attempt to watermark its text generation systems so as to combat bad actors using their services for academic plagiarism or for spam.[29][30],
#  The New York Times relayed in December 2022 that the next version of GPT, GPT-4, has been "rumored" to be launched sometime in 2023.[17]
#  ,
#  Reception and implications Positive reactions ChatGPT was met in December 2022 with generally positive reviews; The New York Times labeled it "the best artificial intelligence chatbot ever released to the general public".[31] Samantha Lock of The Guardian noted that it was able to generate "impressively detailed" and "human-like" text.[32] Technology writer Dan Gillmor used ChatGPT on a student assignment, and found its generated text was on par with what a good student would deliver and opined that "academia has some very serious issues to confront".[33] Alex Kantrowitz of Slate magazine lauded ChatGPT's pushback to questions related to Nazi Germany, including the claim that Adolf Hitler built highways in Germany, which was met with information regarding Nazi Germany's use of forced labor.[34]
#  ,
#  In The Atlantic's "Breakthroughs of the Year" for 2022, Derek Thompson included ChatGPT as part of "the generative-AI eruption" that "may change our mind about how we work, how we think, and what human creativity really is".[35]
#
#  Kelsey Piper of the Vox website wrote that "ChatGPT is the general public's first hands-on introduction to how powerful modern AI has gotten, and as a result, many of us are,
#  [stunned]" and that ChatGPT is "smart enough to be useful despite its flaws".[36] Paul Graham of Y Combinator tweeted that "The striking thing about the reaction to ChatGPT is not just the number of people who are blown away by it, but who they are.,
#  These are not people who get excited by every shiny new thing.,
#  Clearly, something big is happening.,
#  "[37] Elon Musk wrote that "ChatGPT is scary good.,
#  We are not far from dangerously strong AI".[36] Musk paused OpenAI's access to a Twitter database pending a better understanding of OpenAI's plans, stating that "OpenAI was started as open-source and non-profit.,
#  Neither is still true.,
#  "[38][39] Musk had co-founded OpenAI in 2015, in part to address existential risk from artificial intelligence, but had resigned in 2018.[39]
#  ,
#  Google CEO Sundar Pichai upended the work of numerous internal groups in response to the threat of disruption by ChatGPT.[40],
#  In December 2022, Google internally expressed alarm at the unexpected strength of ChatGPT and the newly discovered potential of large language models to disrupt the search engine business, and CEO Sundar Pichai "upended" and reassigned teams within multiple departments to aid in its artificial intelligence products, according to The New York Times.[40],
#  The Information reported on January 3, 2023 that Microsoft Bing was planning to add optional ChatGPT functionality into its public search engine, possibly around March 2023.[41][42]
#
#  Stuart Cobbe, a chartered accountant in England & Wales, decided to the test the ChatGPT chatbot by entering questions from a sample exam paper on the ICAEW website and then entering its answers back into the online test.,
#  ChatGPT scored 42% which, while below the 55% pass mark, was considered a reasonable attempt.]

# %%
# Out:
# [ioneer,
#  Building,
#  ,,
#  San,
#  Francisco,
#  ,,
#  headquarters,
#  of,
#  OpenAI,
#
#  ,
#  Sam,
#  Altman,
#  ,,
#  CEO,
#  of,
#  OpenAI,
#  ChatGPT,
#  was,
#  fine,
#  -,
#  tuned,
#  on,
#  top,
#  of,
#  GPT-3.5,
#  using,
#  supervised,
#  learning,
#  as,
#  well,
#  as,
#  reinforcement,
#  learning.[5,
#  ],
#  Both,
#  approaches,
#  used,
#  human,
#  trainers,
#  to,
#  improve,
#  the,
#  model,
#  's,
#  performance,
#  .,
#  In,
#  the,
#  case,
#  of,
#  supervised,
#  learning,
#  ,,
#  the,
#  model,
#  was,
#  provided,
#  with,
#  conversations,
#  in,
#  which,
#  the,
#  trainers,
#  played,
#  both,
#  sides,
#  :,
#  the,
#  user,
#  and,
#  the,
#  AI,
#  assistant,
#  .,
#  In,
#  the,
#  reinforcement,
#  step,
#  ,,
#  human,
#  trainers,
#  first,
#  ranked,
#  responses,
#  that,
#  the,
#  model,
#  had,
#  created,
#  in,
#  a,
#  previous,
#  conversation,
#  .,
#  These,
#  rankings,
#  were,
#  used,
#  to,
#  create,
#  ',
#  reward,
#  models,
#  ',
#  that,
#  the,
#  model,
#  was,
#  further,
#  fine,
#  -,
#  tuned,
#  on,
#  using,
#  several,
#  iterations,
#  of,
#  Proximal,
#  Policy,
#  Optimization,
#  (,
#  PPO).[6][7,
#  ],
#  Proximal,
#  Policy,
#  Optimization,
#  algorithms,
#  present,
#  a,
#  cost,
#  -,
#  effective,
#  benefit,
#  to,
#  trust,
#  region,
#  policy,
#  optimization,
#  algorithms,
#  ;,
#  they,
#  negate,
#  many,
#  of,
#  the,
#  computationally,
#  expensive,
#  operations,
#  with,
#  faster,
#  performance.[8][9,
#  ],
#  The,
#  models,
#  were,
#  trained,
#  in,
#  collaboration,
#  with,
#  Microsoft,
#  on,
#  their,
#  Azure,
#  supercomputing,
#  infrastructure,
#  .,
#
#  ,
#  In,
#  addition,
#  ,,
#  OpenAI,
#  continues,
#  to,
#  gather,
#  data,
#  from,
#  ChatGPT,
#  users,
#  that,
#  could,
#  be,
#  used,
#  to,
#  further,
#  train,
#  and,
#  fine,
#  -,
#  tune,
#  ChatGPT,
#  .,
#  Users,
#  are,
#  allowed,
#  to,
#  upvote,
#  or,
#  downvote,
#  the,
#  responses,
#  they,
#  receive,
#  from,
#  ChatGPT,
#  ;,
#  upon,
#  upvoting,
#  or,
#  downvoting,
#  ,,
#  they,
#  can,
#  also,
#  fill,
#  out,
#  a,
#  text,
#  field,
#  with,
#  additional,
#  feedback.[10][11][12,
#  ],
#
#  ,
#  Features,
#  and,
#  limitations,
#
#  ,
#  Cropped,
#  screenshot,
#  of,
#  a,
#  conversation,
#  with,
#  ChatGPT,
#  ,,
#  December,
#  30,
#  ,,
#  2022,
#  Although,
#  the,
#  core,
#  function,
#  of,
#  a,
#  chatbot,
#  is,
#  to,
#  mimic,
#  a,
#  human,
#  conversationalist,
#  ,,
#  ChatGPT,
#  is,
#  versatile,
#  .,
#  For,
#  example,
#  ,,
#  it,
#  has,
#  the,
#  ability,
#  to,
#  write,
#  and,
#  debug,
#  computer,
#  programs,
#  ;,
#  to,
#  compose,
#  music,
#  ,,
#  teleplays,
#  ,,
#  fairy,
#  tales,
#  ,,
#  and,
#  student,
#  essays,
#  ;,
#  to,
#  answer,
#  test,
#  questions,
#  (,
#  sometimes,
#  ,,
#  depending,
#  on,
#  the,
#  test,
#  ,,
#  at,
#  a,
#  level,
#  above,
#  the,
#  average,
#  human,
#  test,
#  -,
#  taker);[13,
#  ],
#  to,
#  write,
#  poetry,
#  and,
#  song,
#  lyrics;[14,
#  ],
#  to,
#  emulate,
#  a,
#  Linux,
#  system,
#  ;,
#  to,
#  simulate,
#  an,
#  entire,
#  chat,
#  room,
#  ;,
#  to,
#  play,
#  games,
#  like,
#  tic,
#  -,
#  tac,
#  -,
#  toe,
#  ;,
#  and,
#  to,
#  simulate,
#  an,
#  ATM.[15,
#  ],
#  ChatGPT,
#  's,
#  training,
#  data,
#  includes,
#  man,
#  pages,
#  and,
#  information,
#  about,
#  Internet,
#  phenomena,
#  and,
#  programming,
#  languages,
#  ,,
#  such,
#  as,
#  bulletin,
#  board,
#  systems,
#  and,
#  the,
#  Python,
#  programming,
#  language.[15,
#  ],
#
#  ,
#  In,
#  comparison,
#  to,
#  its,
#  predecessor,
#  ,,
#  InstructGPT,
#  ,,
#  ChatGPT,
#  attempts,
#  to,
#  reduce,
#  harmful,
#  and,
#  deceitful,
#  responses.[16,
#  ],
#  In,
#  one,
#  example,
#  ,,
#  whereas,
#  InstructGPT,
#  accepts,
#  the,
#  premise,
#  of,
#  the,
#  prompt,
#  ",
#  Tell,
#  me,
#  about,
#  when,
#  Christopher,
#  Columbus,
#  came,
#  to,
#  the,
#  US,
#  in,
#  2015,
#  ",
#  as,
#  being,
#  truthful,
#  ,,
#  ChatGPT,
#  acknowledges,
#  the,
#  counterfactual,
#  nature,
#  of,
#  the,
#  question,
#  and,
#  frames,
#  its,
#  answer,
#  as,
#  a,
#  hypothetical,
#  consideration,
#  of,
#  what,
#  might,
#  happen,
#  if,
#  Columbus,
#  came,
#  to,
#  the,
#  U.S.,
#  in,
#  2015,
#  ,,
#  using,
#  information,
#  about,
#  Columbus,
#  ',
#  voyages,
#  and,
#  facts,
#  about,
#  the,
#  modern,
#  world,
#  –,
#  including,
#  modern,
#  perceptions,
#  of,
#  Columbus,
#  ',
#  actions.[6,
#  ],
#
#  ,
#  Unlike,
#  most,
#  chatbots,
#  ,,
#  ChatGPT,
#  remembers,
#  previous,
#  prompts,
#  given,
#  to,
#  it,
#  in,
#  the,
#  same,
#  conversation,
#  ;,
#  journalists,
#  have,
#  suggested,
#  that,
#  this,
#  will,
#  allow,
#  ChatGPT,
#  to,
#  be,
#  used,
#  as,
#  a,
#  personalized,
#  therapist.[17,
#  ],
#  To,
#  prevent,
#  offensive,
#  outputs,
#  from,
#  being,
#  presented,
#  to,
#  and,
#  produced,
#  from,
#  ChatGPT,
#  ,,
#  queries,
#  are,
#  filtered,
#  through,
#  OpenAI,
#  's,
#  company,
#  -,
#  wide,
#  moderation,
#  API,[18][19,
#  ],
#  and,
#  potentially,
#  racist,
#  or,
#  sexist,
#  prompts,
#  are,
#  dismissed.[6][17,
#  ],
#
#  ,
#  ChatGPT,
#  suffers,
#  from,
#  multiple,
#  limitations,
#  .,
#  OpenAI,
#  acknowledged,
#  that,
#  ChatGPT,
#  ",
#  sometimes,
#  writes,
#  plausible,
#  -,
#  sounding,
#  but,
#  incorrect,
#  or,
#  nonsensical,
#  answers".[6,
#  ],
#  This,
#  behavior,
#  is,
#  common,
#  to,
#  large,
#  language,
#  models,
#  and,
#  is,
#  called,
#  hallucination.[20,
#  ],
#  The,
#  reward,
#  model,
#  of,
#  ChatGPT,
#  ,,
#  designed,
#  around,
#  human,
#  oversight,
#  ,,
#  can,
#  be,
#  over,
#  -,
#  optimized,
#  and,
#  thus,
#  hinder,
#  performance,
#  ,,
#  otherwise,
#  known,
#  as,
#  Goodhart,
#  's,
#  law.[21,
#  ],
#  ChatGPT,
#  has,
#  limited,
#  knowledge,
#  of,
#  events,
#  that,
#  occurred,
#  after,
#  2021,
#  .,
#  According,
#  to,
#  the,
#  BBC,
#  ,,
#  as,
#  of,
#  December,
#  2022,
#  ChatGPT,
#  is,
#  not,
#  allowed,
#  to,
#  ",
#  express,
#  political,
#  opinions,
#  or,
#  engage,
#  in,
#  political,
#  activism".[22,
#  ],
#  Yet,
#  ,,
#  research,
#  suggests,
#  that,
#  ChatGPT,
#  exhibits,
#  a,
#  pro,
#  -,
#  environmental,
#  ,,
#  left,
#  -,
#  libertarian,
#  orientation,
#  when,
#  prompted,
#  to,
#  take,
#  a,
#  stance,
#  on,
#  political,
#  statements,
#  from,
#  two,
#  established,
#  voting,
#  advice,
#  applications.[23,
#  ],
#  In,
#  training,
#  ChatGPT,
#  ,,
#  human,
#  reviewers,
#  preferred,
#  longer,
#  answers,
#  ,,
#  irrespective,
#  of,
#  actual,
#  comprehension,
#  or,
#  factual,
#  content.[6,
#  ],
#  Training,
#  data,
#  also,
#  suffers,
#  from,
#  algorithmic,
#  bias,
#  ,,
#  which,
#  may,
#  be,
#  revealed,
#  when,
#  ChatGPT,
#  responds,
#  to,
#  prompts,
#  including,
#  descriptors,
#  of,
#  people,
#  .,
#  In,
#  one,
#  instance,
#  ,,
#  ChatGPT,
#  generated,
#  a,
#  rap,
#  indicating,
#  that,
#  women,
#  and,
#  scientists,
#  of,
#  color,
#  were,
#  inferior,
#  to,
#  white,
#  and,
#  male,
#  scientists.[24][25,
#  ],
#
#  ,
#  Service,
#  ChatGPT,
#  was,
#  launched,
#  on,
#  November,
#  30,
#  ,,
#  2022,
#  ,,
#  by,
#  San,
#  Francisco,
#  -,
#  based,
#  OpenAI,
#  ,,
#  the,
#  creator,
#  of,
#  DALL·E,
#  2,
#  and,
#  Whisper,
#  .,
#  The,
#  service,
#  was,
#  launched,
#  as,
#  initially,
#  free,
#  to,
#  the,
#  public,
#  ,,
#  with,
#  plans,
#  to,
#  monetize,
#  the,
#  service,
#  later.[26,
#  ],
#  By,
#  December,
#  4,
#  ,,
#  OpenAI,
#  estimated,
#  ChatGPT,
#  already,
#  had,
#  over,
#  one,
#  million,
#  users.[10,
#  ],
#  CNBC,
#  wrote,
#  on,
#  December,
#  15,
#  ,,
#  2022,
#  ,,
#  that,
#  the,
#  service,
#  ",
#  still,
#  goes,
#  down,
#  from,
#  time,
#  to,
#  time".[27,
#  ],
#  The,
#  service,
#  works,
#  best,
#  in,
#  English,
#  ,,
#  but,
#  is,
#  also,
#  able,
#  to,
#  function,
#  in,
#  some,
#  other,
#  languages,
#  ,,
#  to,
#  varying,
#  degrees,
#  of,
#  success.[14,
#  ],
#  Unlike,
#  some,
#  other,
#  recent,
#  high,
#  -,
#  profile,
#  advances,
#  in,
#  AI,
#  ,,
#  as,
#  of,
#  December,
#  2022,
#  ,,
#  there,
#  is,
#  no,
#  sign,
#  of,
#  an,
#  official,
#  peer,
#  -,
#  reviewed,
#  technical,
#  paper,
#  about,
#  ChatGPT.[28,
#  ],
#
#  ,
#  According,
#  to,
#  OpenAI,
#  guest,
#  researcher,
#  Scott,
#  Aaronson,
#  ,,
#  OpenAI,
#  is,
#  working,
#  on,
#  a,
#  tool,
#  to,
#  attempt,
#  to,
#  watermark,
#  its,
#  text,
#  generation,
#  systems,
#  so,
#  as,
#  to,
#  combat,
#  bad,
#  actors,
#  using,
#  their,
#  services,
#  for,
#  academic,
#  plagiarism,
#  or,
#  for,
#  spam.[29][30,
#  ],
#  The,
#  New,
#  York,
#  Times,
#  relayed,
#  in,
#  December,
#  2022,
#  that,
#  the,
#  next,
#  version,
#  of,
#  GPT,
#  ,,
#  GPT-4,
#  ,,
#  has,
#  been,
#  ",
#  rumored,
#  ",
#  to,
#  be,
#  launched,
#  sometime,
#  in,
#  2023.[17,
#  ],
#
#  ,
#  Reception,
#  and,
#  implications,
#  Positive,
#  reactions,
#  ChatGPT,
#  was,
#  met,
#  in,
#  December,
#  2022,
#  with,
#  generally,
#  positive,
#  reviews,
#  ;,
#  The,
#  New,
#  York,
#  Times,
#  labeled,
#  it,
#  ",
#  the,
#  best,
#  artificial,
#  intelligence,
#  chatbot,
#  ever,
#  released,
#  to,
#  the,
#  general,
#  public".[31,
#  ],
#  Samantha,
#  Lock,
#  of,
#  The,
#  Guardian,
#  noted,
#  that,
#  it,
#  was,
#  able,
#  to,
#  generate,
#  ",
#  impressively,
#  detailed,
#  ",
#  and,
#  ",
#  human,
#  -,
#  like,
#  ",
#  text.[32,
#  ],
#  Technology,
#  writer,
#  Dan,
#  Gillmor,
#  used,
#  ChatGPT,
#  on,
#  a,
#  student,
#  ...]

# %%
sent_count=0
for sent in doc1.sents:
    sent_count=sent_count+1
print(sent_count)
# Out:
# 33

# %%
#tagger

for token in doc1:
    print(token.text,'==>',token.tag_)
    
spacy.explain('NNS')
# Out:
# ioneer ==> NNP
# Building ==> NNP
# , ==> ,
# San ==> NNP
# Francisco ==> NNP
# , ==> ,
# headquarters ==> NN
# of ==> IN
# OpenAI ==> NNP
#
#
#  ==> _SP
# Sam ==> NNP
# Altman ==> NNP
# , ==> ,
# CEO ==> NNP
# of ==> IN
# OpenAI ==> NNP
# ChatGPT ==> NNP
# was ==> VBD
# fine ==> RB
# - ==> HYPH
# tuned ==> VBN
# on ==> IN
# top ==> NN
# of ==> IN
# GPT-3.5 ==> NN
# using ==> VBG
# supervised ==> JJ
# learning ==> NN
# as ==> RB
# well ==> RB
# as ==> IN
# reinforcement ==> NN
# learning.[5 ==> NN
# ] ==> -RRB-
# Both ==> DT
# approaches ==> NNS
# used ==> VBD
# human ==> JJ
# trainers ==> NNS
# to ==> TO
# improve ==> VB
# the ==> DT
# model ==> NN
# 's ==> POS
# performance ==> NN
# . ==> .
# In ==> IN
# the ==> DT
# case ==> NN
# of ==> IN
# supervised ==> JJ
# learning ==> NN
# , ==> ,
# the ==> DT
# model ==> NN
# was ==> VBD
# provided ==> VBN
# with ==> IN
# conversations ==> NNS
# in ==> IN
# which ==> WDT
# the ==> DT
# trainers ==> NNS
# played ==> VBD
# both ==> DT
# sides ==> NNS
# : ==> :
# the ==> DT
# user ==> NN
# and ==> CC
# the ==> DT
# AI ==> NNP
# assistant ==> NN
# . ==> .
# In ==> IN
# the ==> DT
# reinforcement ==> NN
# step ==> NN
# , ==> ,
# human ==> JJ
# trainers ==> NNS
# first ==> RB
# ranked ==> VBD
# responses ==> NNS
# that ==> IN
# the ==> DT
# model ==> NN
# had ==> VBD
# created ==> VBN
# in ==> IN
# a ==> DT
# previous ==> JJ
# conversation ==> NN
# . ==> .
# These ==> DT
# rankings ==> NNS
# were ==> VBD
# used ==> VBN
# to ==> TO
# create ==> VB
# ' ==> ``
# reward ==> NN
# models ==> NNS
# ' ==> ''
# that ==> IN
# the ==> DT
# model ==> NN
# was ==> VBD
# further ==> RB
# fine ==> RB
# - ==> HYPH
# tuned ==> VBN
# on ==> IN
# using ==> VBG
# several ==> JJ
# iterations ==> NNS
# of ==> IN
# Proximal ==> NNP
# Policy ==> NNP
# Optimization ==> NNP
# ( ==> -LRB-
# PPO).[6][7 ==> NN
# ] ==> XX
# Proximal ==> NNP
# Policy ==> NNP
# Optimization ==> NNP
# algorithms ==> NNS
# present ==> VBP
# a ==> DT
# cost ==> NN
# - ==> HYPH
# effective ==> JJ
# benefit ==> NN
# to ==> TO
# trust ==> VB
# region ==> NN
# policy ==> NN
# optimization ==> NN
# algorithms ==> NNS
# ; ==> :
# they ==> PRP
# negate ==> VBP
# many ==> JJ
# of ==> IN
# the ==> DT
# computationally ==> RB
# expensive ==> JJ
# operations ==> NNS
# with ==> IN
# faster ==> JJR
# performance.[8][9 ==> NNS
# ] ==> -RRB-
# The ==> DT
# models ==> NNS
# were ==> VBD
# trained ==> VBN
# in ==> IN
# collaboration ==> NN
# with ==> IN
# Microsoft ==> NNP
# on ==> IN
# their ==> PRP$
# Azure ==> NNP
# supercomputing ==> NN
# infrastructure ==> NN
# . ==> .
#
#
#  ==> _SP
# In ==> IN
# addition ==> NN
# , ==> ,
# OpenAI ==> NNP
# continues ==> VBZ
# to ==> TO
# gather ==> VB
# data ==> NNS
# from ==> IN
# ChatGPT ==> JJ
# users ==> NNS
# that ==> WDT
# could ==> MD
# be ==> VB
# used ==> VBN
# to ==> TO
# further ==> RB
# train ==> VB
# and ==> CC
# fine ==> JJ
# - ==> HYPH
# tune ==> NN
# ChatGPT ==> NN
# . ==> .
# Users ==> NNS
# are ==> VBP
# allowed ==> VBN
# to ==> TO
# upvote ==> VB
# or ==> CC
# downvote ==> VB
# the ==> DT
# responses ==> NNS
# they ==> PRP
# receive ==> VBP
# from ==> IN
# ChatGPT ==> NNP
# ; ==> :
# upon ==> IN
# upvoting ==> VBG
# or ==> CC
# downvoting ==> JJ
# , ==> ,
# they ==> PRP
# can ==> MD
# also ==> RB
# fill ==> VB
# out ==> RP
# a ==> DT
# text ==> NN
# field ==> NN
# with ==> IN
# additional ==> JJ
# feedback.[10][11][12 ==> NN
# ] ==> -RRB-
#
#
#  ==> _SP
# Features ==> NNPS
# and ==> CC
# limitations ==> NNS
#
#
#  ==> _SP
# Cropped ==> VBD
# screenshot ==> NN
# of ==> IN
# a ==> DT
# conversation ==> NN
# with ==> IN
# ChatGPT ==> NNP
# , ==> ,
# December ==> NNP
# 30 ==> CD
# , ==> ,
# 2022 ==> CD
# Although ==> IN
# the ==> DT
# core ==> NN
# function ==> NN
# of ==> IN
# a ==> DT
# chatbot ==> NN
# is ==> VBZ
# to ==> TO
# mimic ==> VB
# a ==> DT
# human ==> JJ
# conversationalist ==> NN
# , ==> ,
# ChatGPT ==> NNP
# is ==> VBZ
# versatile ==> JJ
# . ==> .
# For ==> IN
# example ==> NN
# , ==> ,
# it ==> PRP
# has ==> VBZ
# the ==> DT
# ability ==> NN
# to ==> TO
# write ==> VB
# and ==> CC
# debug ==> VB
# computer ==> NN
# programs ==> NNS
# ; ==> :
# to ==> TO
# compose ==> VB
# music ==> NN
# , ==> ,
# teleplays ==> NNS
# , ==> ,
# fairy ==> NN
# tales ==> NNS
# , ==> ,
# and ==> CC
# student ==> NN
# essays ==> NNS
# ; ==> :
# to ==> TO
# answer ==> VB
# test ==> NN
# questions ==> NNS
# ( ==> -LRB-
# sometimes ==> RB
# , ==> ,
# depending ==> VBG
# on ==> IN
# the ==> DT
# test ==> NN
# , ==> ,
# at ==> IN
# a ==> DT
# level ==> NN
# above ==> IN
# the ==> DT
# average ==> JJ
# human ==> JJ
# test ==> NN
# - ==> HYPH
# taker);[13 ==> XX
# ] ==> -RRB-
# to ==> TO
# write ==> VB
# poetry ==> NN
# and ==> CC
# song ==> NN
# lyrics;[14 ==> XX
# ] ==> XX
# to ==> TO
# emulate ==> VB
# a ==> DT
# Linux ==> NNP
# system ==> NN
# ; ==> :
# to ==> TO
# simulate ==> VB
# an ==> DT
# entire ==> JJ
# chat ==> NN
# room ==> NN
# ; ==> :
# to ==> TO
# play ==> VB
# games ==> NNS
# like ==> IN
# tic ==> JJ
# - ==> HYPH
# tac ==> NN
# - ==> HYPH
# toe ==> NN
# ; ==> :
# and ==> CC
# to ==> TO
# simulate ==> VB
# an ==> DT
# ATM.[15 ==> NNP
# ] ==> -RRB-
# ChatGPT ==> NNP
# 's ==> POS
# training ==> NN
# data ==> NNS
# includes ==> VBZ
# man ==> NN
# pages ==> NNS
# and ==> CC
# information ==> NN
# about ==> IN
# Internet ==> NN
# phenomena ==> NNS
# and ==> CC
# programming ==> NN
# languages ==> NNS
# , ==> ,
# such ==> JJ
# as ==> IN
# bulletin ==> NNP
# board ==> NN
# systems ==> NNS
# and ==> CC
# the ==> DT
# Python ==> NNP
# programming ==> NN
# language.[15 ==> NN
# ] ==> -RRB-
#
#
#  ==> _SP
# In ==> IN
# comparison ==> NN
# to ==> IN
# its ==> PRP$
# predecessor ==> NN
# , ==> ,
# InstructGPT ==> NN
# , ==> ,
# ChatGPT ==> NN
# attempts ==> NNS
# to ==> TO
# reduce ==> VB
# harmful ==> JJ
# and ==> CC
# deceitful ==> JJ
# responses.[16 ==> NNP
# ] ==> -RRB-
# In ==> IN
# one ==> CD
# example ==> NN
# , ==> ,
# whereas ==> IN
# InstructGPT ==> NN
# accepts ==> VBZ
# the ==> DT
# premise ==> NN
# of ==> IN
# the ==> DT
# prompt ==> NN
# " ==> ``
# Tell ==> VB
# me ==> PRP
# about ==> IN
# when ==> WRB
# Christopher ==> NNP
# Columbus ==> NNP
# came ==> VBD
# to ==> IN
# the ==> DT
# US ==> NNP
# in ==> IN
# 2015 ==> CD
# " ==> ''
# as ==> IN
# being ==> VBG
# truthful ==> JJ
# , ==> ,
# ChatGPT ==> NNP
# acknowledges ==> VBZ
# the ==> DT
# counterfactual ==> JJ
# nature ==> NN
# of ==> IN
# the ==> DT
# question ==> NN
# and ==> CC
# frames ==> VBZ
# its ==> PRP$
# answer ==> NN
# as ==> IN
# a ==> DT
# hypothetical ==> JJ
# consideration ==> NN
# of ==> IN
# what ==> WP
# might ==> MD
# happen ==> VB
# if ==> IN
# Columbus ==> NNP
# came ==> VBD
# to ==> IN
# the ==> DT
# U.S. ==> NNP
# in ==> IN
# 2015 ==> CD
# , ==> ,
# using ==> VBG
# information ==> NN
# about ==> IN
# Columbus ==> NNP
# ' ==> POS
# voyages ==> NNS
# and ==> CC
# facts ==> NNS
# about ==> IN
# the ==> DT
# modern ==> JJ
# world ==> NN
# – ==> :
# including ==> VBG
# modern ==> JJ
# perceptions ==> NNS
# of ==> IN
# Columbus ==> NNP
# ' ==> ''
# actions.[6 ==> NNS
# ] ==> -RRB-
#
#
#  ==> _SP
# Unlike ==> IN
# most ==> JJS
# chatbots ==> NNS
# , ==> ,
# ChatGPT ==> NNP
# remembers ==> VBZ
# previous ==> JJ
# prompts ==> NNS
# given ==> VBN
# to ==> IN
# it ==> PRP
# in ==> IN
# the ==> DT
# same ==> JJ
# conversation ==> NN
# ; ==> :
# journalists ==> NNS
# have ==> VBP
# suggested ==> VBN
# that ==> IN
# this ==> DT
# will ==> MD
# allow ==> VB
# ChatGPT ==> NN
# to ==> TO
# be ==> VB
# used ==> VBN
# as ==> IN
# a ==> DT
# personalized ==> JJ
# therapist.[17 ==> NN
# ] ==> -RRB-
# To ==> TO
# prevent ==> VB
# offensive ==> JJ
# outputs ==> NNS
# from ==> IN
# being ==> VBG
# presented ==> VBN
# to ==> IN
# and ==> CC
# produced ==> VBN
# from ==> IN
# ChatGPT ==> NNP
# , ==> ,
# queries ==> NNS
# are ==> VBP
# filtered ==> VBN
# through ==> IN
# OpenAI ==> NNP
# 's ==> POS
# company ==> NN
# - ==> HYPH
# wide ==> JJ
# moderation ==> NN
# API,[18][19 ==> NNP
# ] ==> -RRB-
# and ==> CC
# potentially ==> RB
# racist ==> JJ
# or ==> CC
# sexist ==> JJ
# prompts ==> NNS
# are ==> VBP
# dismissed.[6][17 ==> NNP
# ] ==> -RRB-
#
#
#  ==> _SP
# ChatGPT ==> VBP
# suffers ==> VBZ
# from ==> IN
# multiple ==> JJ
# limitations ==> NNS
# . ==> .
# OpenAI ==> NNP
# acknowledged ==> VBD
# that ==> IN
# ChatGPT ==> NN
# " ==> ``
# sometimes ==> RB
# writes ==> VBZ
# plausible ==> JJ
# - ==> HYPH
# sounding ==> VBG
# but ==> CC
# incorrect ==> JJ
# or ==> CC
# nonsensical ==> JJ
# answers".[6 ==> XX
# ] ==> -RRB-
# This ==> DT
# behavior ==> NN
# is ==> VBZ
# common ==> JJ
# to ==> IN
# large ==> JJ
# language ==> NN
# models ==> NNS
# and ==> CC
# is ==> VBZ
# called ==> VBN
# hallucination.[20 ==> NNP
# ] ==> -RRB-
# The ==> DT
# reward ==> NN
# model ==> NN
# of ==> IN
# ChatGPT ==> NN
# , ==> ,
# designed ==> VBN
# around ==> IN
# human ==> JJ
# oversight ==> NN
# , ==> ,
# can ==> MD
# be ==> VB
# over ==> RB
# - ==> HYPH
# optimized ==> VBN
# and ==> CC
# thus ==> RB
# hinder ==> NN
# performance ==> NN
# , ==> ,
# otherwise ==> RB
# known ==> VBN
# as ==> IN
# Goodhart ==> NNP
# 's ==> POS
# law.[21 ==> NN
# ] ==> -RRB-
# ChatGPT ==> NNP
# has ==> VBZ
# limited ==> VBN
# knowledge ==> NN
# of ==> IN
# events ==> NNS
# that ==> WDT
# occurred ==> VBD
# after ==> IN
# 2021 ==> CD
# . ==> .
# According ==> VBG
# to ==> IN
# the ==> DT
# BBC ==> NNP
# , ==> ,
# as ==> IN
# of ==> IN
# December ==> NNP
# 2022 ==> CD
# ChatGPT ==> NN
# is ==> VBZ
# not ==> RB
# allowed ==> VBN
# to ==> TO
# " ==> ``
# express ==> VB
# political ==> JJ
# opinions ==> NNS
# or ==> CC
# engage ==> VB
# in ==> IN
# political ==> JJ
# activism".[22 ==> NN
# ] ==> XX
# Yet ==> RB
# , ==> ,
# research ==> NN
# suggests ==> VBZ
# that ==> IN
# ChatGPT ==> NN
# exhibits ==> VBZ
# a ==> DT
# pro ==> JJ
# - ==> JJ
# environmental ==> JJ
# , ==> ,
# left ==> JJ
# - ==> HYPH
# libertarian ==> JJ
# orientation ==> NN
# when ==> WRB
# prompted ==> VBN
# to ==> TO
# take ==> VB
# a ==> DT
# stance ==> NN
# on ==> IN
# political ==> JJ
# statements ==> NNS
# from ==> IN
# two ==> CD
# established ==> VBN
# voting ==> NN
# advice ==> NN
# applications.[23 ==> NN
# ] ==> -RRB-
# In ==> IN
# training ==> VBG
# ChatGPT ==> NN
# , ==> ,
# human ==> JJ
# reviewers ==> NNS
# preferred ==> VBD
# longer ==> JJR
# answers ==> NNS
# , ==> ,
# irrespective ==> RB
# of ==> IN
# actual ==> JJ
# comprehension ==> NN
# or ==> CC
# factual ==> JJ
# content.[6 ==> NN
# ] ==> -RRB-
# Training ==> NN
# data ==> NNS
# also ==> RB
# suffers ==> VBZ
# from ==> IN
# algorithmic ==> JJ
# bias ==> NN
# , ==> ,
# which ==> WDT
# may ==> MD
# be ==> VB
# revealed ==> VBN
# when ==> WRB
# ChatGPT ==> NN
# responds ==> VBZ
# to ==> IN
# prompts ==> NNS
# including ==> VBG
# descriptors ==> NNS
# of ==> IN
# people ==> NNS
# . ==> .
# In ==> IN
# one ==> CD
# instance ==> NN
# , ==> ,
# ChatGPT ==> NNP
# generated ==> VBD
# a ==> DT
# rap ==> NN
# indicating ==> VBG
# that ==> IN
# women ==> NNS
# and ==> CC
# scientists ==> NNS
# of ==> IN
# color ==> NN
# were ==> VBD
# inferior ==> JJ
# to ==> IN
# white ==> JJ
# and ==> CC
# male ==> JJ
# scientists.[24][25 ==> NN
# ] ==> :
#
#
#  ==> _SP
# Service ==> NN
# ChatGPT ==> NNP
# was ==> VBD
# launched ==> VBN
# on ==> IN
# November ==> NNP
# 30 ==> CD
# , ==> ,
# 2022 ==> CD
# , ==> ,
# by ==> IN
# San ==> NNP
# Francisco ==> NNP
# - ==> HYPH
# based ==> VBN
# OpenAI ==> NN
# , ==> ,
# the ==> DT
# creator ==> NN
# of ==> IN
# DALL·E ==> NNP
# 2 ==> CD
# and ==> CC
# Whisper ==> NNP
# . ==> .
# The ==> DT
# service ==> NN
# was ==> VBD
# launched ==> VBN
# as ==> IN
# initially ==> RB
# free ==> JJ
# to ==> IN
# the ==> DT
# public ==> NN
# , ==> ,
# with ==> IN
# plans ==> NNS
# to ==> TO
# monetize ==> VB
# the ==> DT
# service ==> NN
# later.[26 ==> NN
# ] ==> -RRB-
# By ==> IN
# December ==> NNP
# 4 ==> CD
# , ==> ,
# OpenAI ==> NNP
# estimated ==> VBD
# ChatGPT ==> NN
# already ==> RB
# had ==> VBD
# over ==> IN
# one ==> CD
# million ==> CD
# users.[10 ==> NN
# ] ==> -RRB-
# CNBC ==> NNP
# wrote ==> VBD
# on ==> IN
# December ==> NNP
# 15 ==> CD
# , ==> ,
# 2022 ==> CD
# , ==> ,
# that ==> IN
# the ==> DT
# service ==> NN
# " ==> ``
# still ==> RB
# goes ==> VBZ
# down ==> RB
# from ==> IN
# time ==> NN
# to ==> IN
# time".[27 ==> NNP
# ] ==> -RRB-
# The ==> DT
# service ==> NN
# works ==> VBZ
# best ==> RBS
# in ==> IN
# English ==> NNP
# , ==> ,
# but ==> CC
# is ==> VBZ
# also ==> RB
# able ==> JJ
# to ==> TO
# function ==> VB
# in ==> IN
# some ==> DT
# other ==> JJ
# languages ==> NNS
# , ==> ,
# to ==> IN
# varying ==> VBG
# degrees ==> NNS
# of ==> IN
# success.[14 ==> NNP
# ] ==> XX
# Unlike ==> IN
# some ==> DT
# other ==> JJ
# recent ==> JJ
# high ==> JJ
# - ==> HYPH
# profile ==> NN
# advances ==> NNS
# in ==> IN
# AI ==> NNP
# , ==> ,
# as ==> IN
# of ==> IN
# December ==> NNP
# 2022 ==> CD
# , ==> ,
# there ==> EX
# is ==> VBZ
# no ==> DT
# sign ==> NN
# of ==> IN
# an ==> DT
# official ==> JJ
# peer ==> NN
# - ==> HYPH
# reviewed ==> VBN
# technical ==> JJ
# paper ==> NN
# about ==> IN
# ChatGPT.[28 ==> NNP
# ] ==> -RRB-
#
#
#  ==> _SP
# According ==> VBG
# to ==> IN
# OpenAI ==> NN
# guest ==> NN
# researcher ==> NN
# Scott ==> NNP
# Aaronson ==> NNP
# , ==> ,
# OpenAI ==> NNP
# is ==> VBZ
# working ==> VBG
# on ==> IN
# a ==> DT
# tool ==> NN
# to ==> TO
# attempt ==> VB
# to ==> TO
# watermark ==> VB
# its ==> PRP$
# text ==> NN
# generation ==> NN
# systems ==> NNS
# so ==> IN
# as ==> IN
# to ==> TO
# combat ==> VB
# bad ==> JJ
# actors ==> NNS
# using ==> VBG
# their ==> PRP$
# services ==> NNS
# for ==> IN
# academic ==> JJ
# plagiarism ==> NN
# or ==> CC
# for ==> IN
# spam.[29][30 ==> NNS
# ] ==> -RRB-
# The ==> DT
# New ==> NNP
# York ==> NNP
# Times ==> NNP
# relayed ==> VBN
# in ==> IN
# December ==> NNP
# 2022 ==> CD
# that ==> IN
# the ==> DT
# next ==> JJ
# version ==> NN
# of ==> IN
# GPT ==> NNP
# , ==> ,
# GPT-4 ==> NNP
# , ==> ,
# has ==> VBZ
# been ==> VBN
# " ==> ``
# rumored ==> VBN
# " ==> ''
# to ==> TO
# be ==> VB
# launched ==> VBN
# sometime ==> RB
# in ==> IN
# 2023.[17 ==> CD
# ] ==> ADD
#
#
#  ==> _SP
# Reception ==> NN
# and ==> CC
# implications ==> NNS
# Positive ==> JJ
# reactions ==> NNS
# ChatGPT ==> NN
# was ==> VBD
# met ==> VBN
# in ==> IN
# December ==> NNP
# 2022 ==> CD
# with ==> IN
# generally ==> RB
# positive ==> JJ
# reviews ==> NNS
# ; ==> :
# The ==> DT
# New ==> NNP
# York ==> NNP
# Times ==> NNP
# labeled ==> VBD
# it ==> PRP
# " ==> ``
# the ==> DT
# best ==> JJS
# artificial ==> JJ
# intelligence ==> NN
# chatbot ==> NNP
# ever ==> RB
# released ==> VBN
# to ==> IN
# the ==> DT
# general ==> JJ
# public".[31 ==> NN
# ] ==> XX
# Samantha ==> NNP
# Lock ==> NNP
# of ==> IN
# The ==> DT
# Guardian ==> NNP
# noted ==> VBD
# that ==> IN
# it ==> PRP
# was ==> VBD
# able ==> JJ
# to ==> TO
# generate ==> VB
# " ==> ``
# impressively ==> RB
# detailed ==> JJ
# " ==> ''
# and ==> CC
# " ==> ``
# human ==> NN
# - ==> HYPH
# like ==> JJ
# " ==> ``
# text.[32 ==> NN
# ] ==> -RRB-
# Technology ==> NN
# writer ==> NN
# Dan ==> NNP
# Gillmor ==> NNP
# used ==> VBD
# ChatGPT ==> NN
# on ==> IN
# a ==> DT
# student ==> NN
# assignment ==> NN
# , ==> ,
# and ==> CC
# found ==> VBD
# its ==> PRP$
# generated ==> VBN
# text ==> NN
# was ==> VBD
# on ==> IN
# par ==> NN
# with ==> IN
# what ==> WP
# a ==> DT
# good ==> JJ
# student ==> NN
# would ==> MD
# deliver ==> VB
# and ==> CC
# opined ==> VBN
# that ==> IN
# " ==> ``
# academia ==> NN
# has ==> VBZ
# some ==> DT
# very ==> RB
# serious ==> JJ
# issues ==> NNS
# to ==> TO
# confront".[33 ==> VB
# ] ==> -RRB-
# Alex ==> NNP
# Kantrowitz ==> NNP
# of ==> IN
# Slate ==> NNP
# magazine ==> NN
# lauded ==> VBD
# ChatGPT ==> NNP
# 's ==> POS
# pushback ==> NN
# to ==> IN
# questions ==> NNS
# related ==> VBN
# to ==> IN
# Nazi ==> NNP
# Germany ==> NNP
# , ==> ,
# including ==> VBG
# the ==> DT
# claim ==> NN
# that ==> IN
# Adolf ==> NNP
# Hitler ==> NNP
# built ==> VBD
# highways ==> NNS
# in ==> IN
# Germany ==> NNP
# , ==> ,
# which ==> WDT
# was ==> VBD
# met ==> VBN
# with ==> IN
# information ==> NN
# regarding ==> VBG
# Nazi ==> NNP
# Germany ==> NNP
# 's ==> POS
# use ==> NN
# of ==> IN
# forced ==> JJ
# labor.[34 ==> NN
# ] ==> -RRB-
#
#
#  ==> _SP
# In ==> IN
# The ==> DT
# Atlantic ==> NNP
# 's ==> POS
# " ==> ``
# Breakthroughs ==> NNP
# of ==> IN
# the ==> DT
# Year ==> NN
# " ==> ''
# for ==> IN
# 2022 ==> CD
# , ==> ,
# Derek ==> NNP
# Thompson ==> NNP
# included ==> VBD
# ChatGPT ==> NN
# as ==> IN
# part ==> NN
# of ==> IN
# " ==> ``
# the ==> DT
# generative ==> JJ
# - ==> HYPH
# AI ==> NN
# eruption ==> NN
# " ==> ''
# that ==> WDT
# " ==> ``
# may ==> MD
# change ==> VB
# our ==> PRP$
# mind ==> NN
# about ==> IN
# how ==> WRB
# we ==> PRP
# work ==> VBP
# , ==> ,
# how ==> WRB
# we ==> PRP
# think ==> VBP
# , ==> ,
# and ==> CC
# what ==> WP
# human ==> JJ
# creativity ==> NN
# really ==> RB
# is".[35 ==> JJ
# ] ==> XX
#
#
#  ==> _SP
# Kelsey ==> NNP
# Piper ==> NNP
# of ==> IN
# the ==> DT
# Vox ==> NNP
# website ==> NN
# wrote ==> VBD
# that ==> IN
# " ==> ``
# ChatGPT ==> NN
# is ==> VBZ
# the ==> DT
# general ==> JJ
# public ==> NN
# 's ==> POS
# first ==> JJ
# hands ==> NNS
# - ==> HYPH
# on ==> RP
# introduction ==> NN
# to ==> IN
# how ==> WRB
# powerful ==> JJ
# modern ==> JJ
# AI ==> NNP
# has ==> VBZ
# gotten ==> VBN
# , ==> ,
# and ==> CC
# as ==> IN
# a ==> DT
# result ==> NN
# , ==> ,
# many ==> JJ
# of ==> IN
# us ==> PRP
# are ==> VBP
# [ ==> XX
# stunned ==> VBN
# ] ==> -RRB-
# " ==> ''
# and ==> CC
# that ==> DT
# ChatGPT ==> NN
# is ==> VBZ
# " ==> ``
# smart ==> JJ
# enough ==> RB
# to ==> TO
# be ==> VB
# useful ==> JJ
# despite ==> IN
# its ==> PRP$
# flaws".[36 ==> NN
# ] ==> -RRB-
# Paul ==> NNP
# Graham ==> NNP
# of ==> IN
# Y ==> NNP
# Combinator ==> NNP
# tweeted ==> VBD
# that ==> IN
# " ==> ``
# The ==> DT
# striking ==> JJ
# thing ==> NN
# about ==> IN
# the ==> DT
# reaction ==> NN
# to ==> IN
# ChatGPT ==> NNP
# is ==> VBZ
# not ==> RB
# just ==> RB
# the ==> DT
# number ==> NN
# of ==> IN
# people ==> NNS
# who ==> WP
# are ==> VBP
# blown ==> VBN
# away ==> RB
# by ==> IN
# it ==> PRP
# , ==> ,
# but ==> CC
# who ==> WP
# they ==> PRP
# are ==> VBP
# . ==> .
# These ==> DT
# are ==> VBP
# not ==> RB
# people ==> NNS
# who ==> WP
# get ==> VBP
# excited ==> VBN
# by ==> IN
# every ==> DT
# shiny ==> JJ
# new ==> JJ
# thing ==> NN
# . ==> .
# Clearly ==> RB
# , ==> ,
# something ==> NN
# big ==> JJ
# is ==> VBZ
# happening ==> VBG
# . ==> .
# "[37 ==> NFP
# ] ==> -RRB-
# Elon ==> NNP
# Musk ==> NNP
# wrote ==> VBD
# that ==> IN
# " ==> ``
# ChatGPT ==> NN
# is ==> VBZ
# scary ==> JJ
# good ==> NN
# . ==> .
# We ==> PRP
# are ==> VBP
# not ==> RB
# far ==> RB
# from ==> IN
# dangerously ==> RB
# strong ==> JJ
# AI".[36 ==> NNP
# ] ==> -RRB-
# Musk ==> NNP
# paused ==> VBD
# OpenAI ==> NNP
# 's ==> POS
# access ==> NN
# to ==> IN
# a ==> DT
# Twitter ==> NNP
# database ==> NN
# pending ==> VBG
# a ==> DT
# better ==> JJR
# understanding ==> NN
# of ==> IN
# OpenAI ==> NNP
# 's ==> POS
# plans ==> NNS
# , ==> ,
# stating ==> VBG
# that ==> IN
# " ==> ``
# OpenAI ==> NN
# was ==> VBD
# started ==> VBN
# as ==> IN
# open ==> JJ
# - ==> HYPH
# source ==> NN
# and ==> CC
# non ==> JJ
# - ==> JJ
# profit ==> NN
# . ==> .
# Neither ==> DT
# is ==> VBZ
# still ==> RB
# true ==> JJ
# . ==> .
# "[38][39 ==> _SP
# ] ==> -RRB-
# Musk ==> NNP
# had ==> VBD
# co ==> VBN
# - ==> VBN
# founded ==> VBN
# OpenAI ==> NN
# in ==> IN
# 2015 ==> CD
# , ==> ,
# in ==> IN
# part ==> NN
# to ==> TO
# address ==> VB
# existential ==> JJ
# risk ==> NN
# from ==> IN
# artificial ==> JJ
# intelligence ==> NN
# , ==> ,
# but ==> CC
# had ==> VBD
# resigned ==> VBN
# in ==> IN
# 2018.[39 ==> CD
# ] ==> ADD
#
#
#  ==> _SP
# Google ==> NNP
# CEO ==> NNP
# Sundar ==> NNP
# Pichai ==> NNP
# upended ==> VBD
# the ==> DT
# work ==> NN
# of ==> IN
# numerous ==> JJ
# internal ==> JJ
# groups ==> NNS
# in ==> IN
# response ==> NN
# to ==> IN
# the ==> DT
# threat ==> NN
# of ==> IN
# disruption ==> NN
# by ==> IN
# ChatGPT.[40 ==> NN
# ] ==> -RRB-
# In ==> IN
# December ==> NNP
# 2022 ==> CD
# , ==> ,
# Google ==> NNP
# internally ==> RB
# expressed ==> VBD
# alarm ==> NN
# at ==> IN
# the ==> DT
# unexpected ==> JJ
# strength ==> NN
# of ==> IN
# ChatGPT ==> NN
# and ==> CC
# the ==> DT
# newly ==> RB
# discovered ==> VBN
# potential ==> NN
# of ==> IN
# large ==> JJ
# language ==> NN
# models ==> NNS
# to ==> TO
# disrupt ==> VB
# the ==> DT
# search ==> NN
# engine ==> NN
# business ==> NN
# , ==> ,
# and ==> CC
# CEO ==> NNP
# Sundar ==> NNP
# Pichai ==> NNP
# " ==> ``
# upended ==> JJ
# " ==> ''
# and ==> CC
# reassigned ==> VBD
# teams ==> NNS
# within ==> IN
# multiple ==> JJ
# departments ==> NNS
# to ==> TO
# aid ==> VB
# in ==> IN
# its ==> PRP$
# artificial ==> JJ
# intelligence ==> NN
# products ==> NNS
# , ==> ,
# according ==> VBG
# to ==> IN
# The ==> DT
# New ==> NNP
# York ==> NNP
# Times.[40 ==> NN
# ] ==> -RRB-
# The ==> DT
# Information ==> NN
# reported ==> VBD
# on ==> IN
# January ==> NNP
# 3 ==> CD
# , ==> ,
# 2023 ==> CD
# that ==> IN
# Microsoft ==> NNP
# Bing ==> NNP
# was ==> VBD
# planning ==> VBG
# to ==> TO
# add ==> VB
# optional ==> JJ
# ChatGPT ==> JJ
# functionality ==> NN
# into ==> IN
# its ==> PRP$
# public ==> JJ
# search ==> NN
# engine ==> NN
# , ==> ,
# possibly ==> RB
# around ==> IN
# March ==> NNP
# 2023.[41][42 ==> CD
# ] ==> ADD
#
#
#  ==> _SP
# Stuart ==> NNP
# Cobbe ==> NNP
# , ==> ,
# a ==> DT
# chartered ==> JJ
# accountant ==> NN
# in ==> IN
# England ==> NNP
# & ==> CC
# Wales ==> NNP
# , ==> ,
# decided ==> VBD
# to ==> IN
# the ==> DT
# test ==> NN
# the ==> DT
# ChatGPT ==> NNP
# chatbot ==> NN
# by ==> IN
# entering ==> VBG
# questions ==> NNS
# from ==> IN
# a ==> DT
# sample ==> NN
# exam ==> NN
# paper ==> NN
# on ==> IN
# the ==> DT
# ICAEW ==> JJ
# website ==> NN
# and ==> CC
# then ==> RB
# entering ==> VBG
# its ==> PRP$
# answers ==> NNS
# back ==> RB
# into ==> IN
# the ==> DT
# online ==> JJ
# test ==> NN
# . ==> .
# ChatGPT ==> NNP
# scored ==> VBD
# 42 ==> CD
# % ==> NN
# which ==> WDT
# , ==> ,
# while ==> IN
# below ==> IN
# the ==> DT
# 55 ==> CD
# % ==> NN
# pass ==> NN
# mark ==> NN
# , ==> ,
# was ==> VBD
# considered ==> VBN
# a ==> DT
# reasonable ==> JJ
# attempt ==> NN
# . ==> .
# 'noun, plural'

# %%
##POS
for token in doc1:
    print(token.text,'==>',token.pos_)
# Out:
# ioneer ==> PROPN
# Building ==> PROPN
# , ==> PUNCT
# San ==> PROPN
# Francisco ==> PROPN
# , ==> PUNCT
# headquarters ==> NOUN
# of ==> ADP
# OpenAI ==> PROPN
#
#
#  ==> SPACE
# Sam ==> PROPN
# Altman ==> PROPN
# , ==> PUNCT
# CEO ==> PROPN
# of ==> ADP
# OpenAI ==> PROPN
# ChatGPT ==> PROPN
# was ==> AUX
# fine ==> ADV
# - ==> PUNCT
# tuned ==> VERB
# on ==> ADP
# top ==> NOUN
# of ==> ADP
# GPT-3.5 ==> NOUN
# using ==> VERB
# supervised ==> ADJ
# learning ==> NOUN
# as ==> ADV
# well ==> ADV
# as ==> ADP
# reinforcement ==> NOUN
# learning.[5 ==> NOUN
# ] ==> PUNCT
# Both ==> DET
# approaches ==> NOUN
# used ==> VERB
# human ==> ADJ
# trainers ==> NOUN
# to ==> PART
# improve ==> VERB
# the ==> DET
# model ==> NOUN
# 's ==> PART
# performance ==> NOUN
# . ==> PUNCT
# In ==> ADP
# the ==> DET
# case ==> NOUN
# of ==> ADP
# supervised ==> ADJ
# learning ==> NOUN
# , ==> PUNCT
# the ==> DET
# model ==> NOUN
# was ==> AUX
# provided ==> VERB
# with ==> ADP
# conversations ==> NOUN
# in ==> ADP
# which ==> PRON
# the ==> DET
# trainers ==> NOUN
# played ==> VERB
# both ==> DET
# sides ==> NOUN
# : ==> PUNCT
# the ==> DET
# user ==> NOUN
# and ==> CCONJ
# the ==> DET
# AI ==> PROPN
# assistant ==> NOUN
# . ==> PUNCT
# In ==> ADP
# the ==> DET
# reinforcement ==> NOUN
# step ==> NOUN
# , ==> PUNCT
# human ==> ADJ
# trainers ==> NOUN
# first ==> ADV
# ranked ==> VERB
# responses ==> NOUN
# that ==> SCONJ
# the ==> DET
# model ==> NOUN
# had ==> AUX
# created ==> VERB
# in ==> ADP
# a ==> DET
# previous ==> ADJ
# conversation ==> NOUN
# . ==> PUNCT
# These ==> DET
# rankings ==> NOUN
# were ==> AUX
# used ==> VERB
# to ==> PART
# create ==> VERB
# ' ==> PUNCT
# reward ==> NOUN
# models ==> NOUN
# ' ==> PUNCT
# that ==> SCONJ
# the ==> DET
# model ==> NOUN
# was ==> AUX
# further ==> ADV
# fine ==> ADV
# - ==> PUNCT
# tuned ==> VERB
# on ==> ADP
# using ==> VERB
# several ==> ADJ
# iterations ==> NOUN
# of ==> ADP
# Proximal ==> PROPN
# Policy ==> PROPN
# Optimization ==> PROPN
# ( ==> PUNCT
# PPO).[6][7 ==> NOUN
# ] ==> X
# Proximal ==> PROPN
# Policy ==> PROPN
# Optimization ==> PROPN
# algorithms ==> NOUN
# present ==> VERB
# a ==> DET
# cost ==> NOUN
# - ==> PUNCT
# effective ==> ADJ
# benefit ==> NOUN
# to ==> PART
# trust ==> VERB
# region ==> NOUN
# policy ==> NOUN
# optimization ==> NOUN
# algorithms ==> NOUN
# ; ==> PUNCT
# they ==> PRON
# negate ==> VERB
# many ==> ADJ
# of ==> ADP
# the ==> DET
# computationally ==> ADV
# expensive ==> ADJ
# operations ==> NOUN
# with ==> ADP
# faster ==> ADJ
# performance.[8][9 ==> NOUN
# ] ==> PUNCT
# The ==> DET
# models ==> NOUN
# were ==> AUX
# trained ==> VERB
# in ==> ADP
# collaboration ==> NOUN
# with ==> ADP
# Microsoft ==> PROPN
# on ==> ADP
# their ==> PRON
# Azure ==> PROPN
# supercomputing ==> NOUN
# infrastructure ==> NOUN
# . ==> PUNCT
#
#
#  ==> SPACE
# In ==> ADP
# addition ==> NOUN
# , ==> PUNCT
# OpenAI ==> PROPN
# continues ==> VERB
# to ==> PART
# gather ==> VERB
# data ==> NOUN
# from ==> ADP
# ChatGPT ==> ADJ
# users ==> NOUN
# that ==> PRON
# could ==> AUX
# be ==> AUX
# used ==> VERB
# to ==> PART
# further ==> ADV
# train ==> VERB
# and ==> CCONJ
# fine ==> ADJ
# - ==> PUNCT
# tune ==> NOUN
# ChatGPT ==> NOUN
# . ==> PUNCT
# Users ==> NOUN
# are ==> AUX
# allowed ==> VERB
# to ==> PART
# upvote ==> VERB
# or ==> CCONJ
# downvote ==> VERB
# the ==> DET
# responses ==> NOUN
# they ==> PRON
# receive ==> VERB
# from ==> ADP
# ChatGPT ==> PROPN
# ; ==> PUNCT
# upon ==> SCONJ
# upvoting ==> VERB
# or ==> CCONJ
# downvoting ==> ADJ
# , ==> PUNCT
# they ==> PRON
# can ==> AUX
# also ==> ADV
# fill ==> VERB
# out ==> ADP
# a ==> DET
# text ==> NOUN
# field ==> NOUN
# with ==> ADP
# additional ==> ADJ
# feedback.[10][11][12 ==> NOUN
# ] ==> PUNCT
#
#
#  ==> SPACE
# Features ==> PROPN
# and ==> CCONJ
# limitations ==> NOUN
#
#
#  ==> SPACE
# Cropped ==> VERB
# screenshot ==> NOUN
# of ==> ADP
# a ==> DET
# conversation ==> NOUN
# with ==> ADP
# ChatGPT ==> PROPN
# , ==> PUNCT
# December ==> PROPN
# 30 ==> NUM
# , ==> PUNCT
# 2022 ==> NUM
# Although ==> SCONJ
# the ==> DET
# core ==> NOUN
# function ==> NOUN
# of ==> ADP
# a ==> DET
# chatbot ==> NOUN
# is ==> AUX
# to ==> PART
# mimic ==> VERB
# a ==> DET
# human ==> ADJ
# conversationalist ==> NOUN
# , ==> PUNCT
# ChatGPT ==> PROPN
# is ==> AUX
# versatile ==> ADJ
# . ==> PUNCT
# For ==> ADP
# example ==> NOUN
# , ==> PUNCT
# it ==> PRON
# has ==> VERB
# the ==> DET
# ability ==> NOUN
# to ==> PART
# write ==> VERB
# and ==> CCONJ
# debug ==> VERB
# computer ==> NOUN
# programs ==> NOUN
# ; ==> PUNCT
# to ==> PART
# compose ==> VERB
# music ==> NOUN
# , ==> PUNCT
# teleplays ==> NOUN
# , ==> PUNCT
# fairy ==> NOUN
# tales ==> NOUN
# , ==> PUNCT
# and ==> CCONJ
# student ==> NOUN
# essays ==> NOUN
# ; ==> PUNCT
# to ==> PART
# answer ==> VERB
# test ==> NOUN
# questions ==> NOUN
# ( ==> PUNCT
# sometimes ==> ADV
# , ==> PUNCT
# depending ==> VERB
# on ==> ADP
# the ==> DET
# test ==> NOUN
# , ==> PUNCT
# at ==> ADP
# a ==> DET
# level ==> NOUN
# above ==> ADP
# the ==> DET
# average ==> ADJ
# human ==> ADJ
# test ==> NOUN
# - ==> PUNCT
# taker);[13 ==> X
# ] ==> PUNCT
# to ==> PART
# write ==> VERB
# poetry ==> NOUN
# and ==> CCONJ
# song ==> NOUN
# lyrics;[14 ==> X
# ] ==> X
# to ==> PART
# emulate ==> VERB
# a ==> DET
# Linux ==> PROPN
# system ==> NOUN
# ; ==> PUNCT
# to ==> PART
# simulate ==> VERB
# an ==> DET
# entire ==> ADJ
# chat ==> NOUN
# room ==> NOUN
# ; ==> PUNCT
# to ==> PART
# play ==> VERB
# games ==> NOUN
# like ==> ADP
# tic ==> ADJ
# - ==> PUNCT
# tac ==> NOUN
# - ==> PUNCT
# toe ==> NOUN
# ; ==> PUNCT
# and ==> CCONJ
# to ==> PART
# simulate ==> VERB
# an ==> DET
# ATM.[15 ==> PROPN
# ] ==> PUNCT
# ChatGPT ==> PROPN
# 's ==> PART
# training ==> NOUN
# data ==> NOUN
# includes ==> VERB
# man ==> NOUN
# pages ==> NOUN
# and ==> CCONJ
# information ==> NOUN
# about ==> ADP
# Internet ==> NOUN
# phenomena ==> NOUN
# and ==> CCONJ
# programming ==> NOUN
# languages ==> NOUN
# , ==> PUNCT
# such ==> ADJ
# as ==> ADP
# bulletin ==> PROPN
# board ==> NOUN
# systems ==> NOUN
# and ==> CCONJ
# the ==> DET
# Python ==> PROPN
# programming ==> NOUN
# language.[15 ==> NOUN
# ] ==> PUNCT
#
#
#  ==> SPACE
# In ==> ADP
# comparison ==> NOUN
# to ==> ADP
# its ==> PRON
# predecessor ==> NOUN
# , ==> PUNCT
# InstructGPT ==> NOUN
# , ==> PUNCT
# ChatGPT ==> NOUN
# attempts ==> NOUN
# to ==> PART
# reduce ==> VERB
# harmful ==> ADJ
# and ==> CCONJ
# deceitful ==> ADJ
# responses.[16 ==> PROPN
# ] ==> PUNCT
# In ==> ADP
# one ==> NUM
# example ==> NOUN
# , ==> PUNCT
# whereas ==> SCONJ
# InstructGPT ==> NOUN
# accepts ==> VERB
# the ==> DET
# premise ==> NOUN
# of ==> ADP
# the ==> DET
# prompt ==> NOUN
# " ==> PUNCT
# Tell ==> VERB
# me ==> PRON
# about ==> ADP
# when ==> SCONJ
# Christopher ==> PROPN
# Columbus ==> PROPN
# came ==> VERB
# to ==> ADP
# the ==> DET
# US ==> PROPN
# in ==> ADP
# 2015 ==> NUM
# " ==> PUNCT
# as ==> ADP
# being ==> AUX
# truthful ==> ADJ
# , ==> PUNCT
# ChatGPT ==> PROPN
# acknowledges ==> VERB
# the ==> DET
# counterfactual ==> ADJ
# nature ==> NOUN
# of ==> ADP
# the ==> DET
# question ==> NOUN
# and ==> CCONJ
# frames ==> VERB
# its ==> PRON
# answer ==> NOUN
# as ==> ADP
# a ==> DET
# hypothetical ==> ADJ
# consideration ==> NOUN
# of ==> ADP
# what ==> PRON
# might ==> AUX
# happen ==> VERB
# if ==> SCONJ
# Columbus ==> PROPN
# came ==> VERB
# to ==> ADP
# the ==> DET
# U.S. ==> PROPN
# in ==> ADP
# 2015 ==> NUM
# , ==> PUNCT
# using ==> VERB
# information ==> NOUN
# about ==> ADP
# Columbus ==> PROPN
# ' ==> PART
# voyages ==> NOUN
# and ==> CCONJ
# facts ==> NOUN
# about ==> ADP
# the ==> DET
# modern ==> ADJ
# world ==> NOUN
# – ==> PUNCT
# including ==> VERB
# modern ==> ADJ
# perceptions ==> NOUN
# of ==> ADP
# Columbus ==> PROPN
# ' ==> PUNCT
# actions.[6 ==> NOUN
# ] ==> PUNCT
#
#
#  ==> SPACE
# Unlike ==> ADP
# most ==> ADJ
# chatbots ==> NOUN
# , ==> PUNCT
# ChatGPT ==> PROPN
# remembers ==> VERB
# previous ==> ADJ
# prompts ==> NOUN
# given ==> VERB
# to ==> ADP
# it ==> PRON
# in ==> ADP
# the ==> DET
# same ==> ADJ
# conversation ==> NOUN
# ; ==> PUNCT
# journalists ==> NOUN
# have ==> AUX
# suggested ==> VERB
# that ==> SCONJ
# this ==> PRON
# will ==> AUX
# allow ==> VERB
# ChatGPT ==> NOUN
# to ==> PART
# be ==> AUX
# used ==> VERB
# as ==> ADP
# a ==> DET
# personalized ==> ADJ
# therapist.[17 ==> NOUN
# ] ==> PUNCT
# To ==> PART
# prevent ==> VERB
# offensive ==> ADJ
# outputs ==> NOUN
# from ==> ADP
# being ==> AUX
# presented ==> VERB
# to ==> ADP
# and ==> CCONJ
# produced ==> VERB
# from ==> ADP
# ChatGPT ==> PROPN
# , ==> PUNCT
# queries ==> NOUN
# are ==> AUX
# filtered ==> VERB
# through ==> ADP
# OpenAI ==> PROPN
# 's ==> PART
# company ==> NOUN
# - ==> PUNCT
# wide ==> ADJ
# moderation ==> NOUN
# API,[18][19 ==> PROPN
# ] ==> PUNCT
# and ==> CCONJ
# potentially ==> ADV
# racist ==> ADJ
# or ==> CCONJ
# sexist ==> ADJ
# prompts ==> NOUN
# are ==> AUX
# dismissed.[6][17 ==> PROPN
# ] ==> PUNCT
#
#
#  ==> SPACE
# ChatGPT ==> VERB
# suffers ==> VERB
# from ==> ADP
# multiple ==> ADJ
# limitations ==> NOUN
# . ==> PUNCT
# OpenAI ==> PROPN
# acknowledged ==> VERB
# that ==> SCONJ
# ChatGPT ==> NOUN
# " ==> PUNCT
# sometimes ==> ADV
# writes ==> VERB
# plausible ==> ADJ
# - ==> PUNCT
# sounding ==> VERB
# but ==> CCONJ
# incorrect ==> ADJ
# or ==> CCONJ
# nonsensical ==> ADJ
# answers".[6 ==> X
# ] ==> PUNCT
# This ==> DET
# behavior ==> NOUN
# is ==> AUX
# common ==> ADJ
# to ==> ADP
# large ==> ADJ
# language ==> NOUN
# models ==> NOUN
# and ==> CCONJ
# is ==> AUX
# called ==> VERB
# hallucination.[20 ==> PROPN
# ] ==> PUNCT
# The ==> DET
# reward ==> NOUN
# model ==> NOUN
# of ==> ADP
# ChatGPT ==> NOUN
# , ==> PUNCT
# designed ==> VERB
# around ==> ADP
# human ==> ADJ
# oversight ==> NOUN
# , ==> PUNCT
# can ==> AUX
# be ==> AUX
# over ==> ADV
# - ==> PUNCT
# optimized ==> VERB
# and ==> CCONJ
# thus ==> ADV
# hinder ==> NOUN
# performance ==> NOUN
# , ==> PUNCT
# otherwise ==> ADV
# known ==> VERB
# as ==> ADP
# Goodhart ==> PROPN
# 's ==> PART
# law.[21 ==> NOUN
# ] ==> PUNCT
# ChatGPT ==> PROPN
# has ==> AUX
# limited ==> VERB
# knowledge ==> NOUN
# of ==> ADP
# events ==> NOUN
# that ==> PRON
# occurred ==> VERB
# after ==> ADP
# 2021 ==> NUM
# . ==> PUNCT
# According ==> VERB
# to ==> ADP
# the ==> DET
# BBC ==> PROPN
# , ==> PUNCT
# as ==> ADP
# of ==> ADP
# December ==> PROPN
# 2022 ==> NUM
# ChatGPT ==> NOUN
# is ==> AUX
# not ==> PART
# allowed ==> VERB
# to ==> PART
# " ==> PUNCT
# express ==> VERB
# political ==> ADJ
# opinions ==> NOUN
# or ==> CCONJ
# engage ==> VERB
# in ==> ADP
# political ==> ADJ
# activism".[22 ==> NOUN
# ] ==> X
# Yet ==> ADV
# , ==> PUNCT
# research ==> NOUN
# suggests ==> VERB
# that ==> SCONJ
# ChatGPT ==> NOUN
# exhibits ==> VERB
# a ==> DET
# pro ==> ADJ
# - ==> ADJ
# environmental ==> ADJ
# , ==> PUNCT
# left ==> ADJ
# - ==> PUNCT
# libertarian ==> ADJ
# orientation ==> NOUN
# when ==> SCONJ
# prompted ==> VERB
# to ==> PART
# take ==> VERB
# a ==> DET
# stance ==> NOUN
# on ==> ADP
# political ==> ADJ
# statements ==> NOUN
# from ==> ADP
# two ==> NUM
# established ==> VERB
# voting ==> NOUN
# advice ==> NOUN
# applications.[23 ==> NOUN
# ] ==> PUNCT
# In ==> ADP
# training ==> VERB
# ChatGPT ==> NOUN
# , ==> PUNCT
# human ==> ADJ
# reviewers ==> NOUN
# preferred ==> VERB
# longer ==> ADJ
# answers ==> NOUN
# , ==> PUNCT
# irrespective ==> ADV
# of ==> ADP
# actual ==> ADJ
# comprehension ==> NOUN
# or ==> CCONJ
# factual ==> ADJ
# content.[6 ==> NOUN
# ] ==> PUNCT
# Training ==> NOUN
# data ==> NOUN
# also ==> ADV
# suffers ==> VERB
# from ==> ADP
# algorithmic ==> ADJ
# bias ==> NOUN
# , ==> PUNCT
# which ==> PRON
# may ==> AUX
# be ==> AUX
# revealed ==> VERB
# when ==> SCONJ
# ChatGPT ==> NOUN
# responds ==> VERB
# to ==> ADP
# prompts ==> NOUN
# including ==> VERB
# descriptors ==> NOUN
# of ==> ADP
# people ==> NOUN
# . ==> PUNCT
# In ==> ADP
# one ==> NUM
# instance ==> NOUN
# , ==> PUNCT
# ChatGPT ==> PROPN
# generated ==> VERB
# a ==> DET
# rap ==> NOUN
# indicating ==> VERB
# that ==> SCONJ
# women ==> NOUN
# and ==> CCONJ
# scientists ==> NOUN
# of ==> ADP
# color ==> NOUN
# were ==> AUX
# inferior ==> ADJ
# to ==> ADP
# white ==> ADJ
# and ==> CCONJ
# male ==> ADJ
# scientists.[24][25 ==> NOUN
# ] ==> PUNCT
#
#
#  ==> SPACE
# Service ==> NOUN
# ChatGPT ==> PROPN
# was ==> AUX
# launched ==> VERB
# on ==> ADP
# November ==> PROPN
# 30 ==> NUM
# , ==> PUNCT
# 2022 ==> NUM
# , ==> PUNCT
# by ==> ADP
# San ==> PROPN
# Francisco ==> PROPN
# - ==> PUNCT
# based ==> VERB
# OpenAI ==> NOUN
# , ==> PUNCT
# the ==> DET
# creator ==> NOUN
# of ==> ADP
# DALL·E ==> PROPN
# 2 ==> NUM
# and ==> CCONJ
# Whisper ==> PROPN
# . ==> PUNCT
# The ==> DET
# service ==> NOUN
# was ==> AUX
# launched ==> VERB
# as ==> ADP
# initially ==> ADV
# free ==> ADJ
# to ==> ADP
# the ==> DET
# public ==> NOUN
# , ==> PUNCT
# with ==> ADP
# plans ==> NOUN
# to ==> PART
# monetize ==> VERB
# the ==> DET
# service ==> NOUN
# later.[26 ==> NOUN
# ] ==> PUNCT
# By ==> ADP
# December ==> PROPN
# 4 ==> NUM
# , ==> PUNCT
# OpenAI ==> PROPN
# estimated ==> VERB
# ChatGPT ==> NOUN
# already ==> ADV
# had ==> VERB
# over ==> ADP
# one ==> NUM
# million ==> NUM
# users.[10 ==> NOUN
# ] ==> PUNCT
# CNBC ==> PROPN
# wrote ==> VERB
# on ==> ADP
# December ==> PROPN
# 15 ==> NUM
# , ==> PUNCT
# 2022 ==> NUM
# , ==> PUNCT
# that ==> SCONJ
# the ==> DET
# service ==> NOUN
# " ==> PUNCT
# still ==> ADV
# goes ==> VERB
# down ==> ADV
# from ==> ADP
# time ==> NOUN
# to ==> ADP
# time".[27 ==> PROPN
# ] ==> PUNCT
# The ==> DET
# service ==> NOUN
# works ==> VERB
# best ==> ADV
# in ==> ADP
# English ==> PROPN
# , ==> PUNCT
# but ==> CCONJ
# is ==> AUX
# also ==> ADV
# able ==> ADJ
# to ==> PART
# function ==> VERB
# in ==> ADP
# some ==> DET
# other ==> ADJ
# languages ==> NOUN
# , ==> PUNCT
# to ==> ADP
# varying ==> VERB
# degrees ==> NOUN
# of ==> ADP
# success.[14 ==> PROPN
# ] ==> X
# Unlike ==> ADP
# some ==> DET
# other ==> ADJ
# recent ==> ADJ
# high ==> ADJ
# - ==> PUNCT
# profile ==> NOUN
# advances ==> NOUN
# in ==> ADP
# AI ==> PROPN
# , ==> PUNCT
# as ==> ADP
# of ==> ADP
# December ==> PROPN
# 2022 ==> NUM
# , ==> PUNCT
# there ==> PRON
# is ==> VERB
# no ==> DET
# sign ==> NOUN
# of ==> ADP
# an ==> DET
# official ==> ADJ
# peer ==> NOUN
# - ==> PUNCT
# reviewed ==> VERB
# technical ==> ADJ
# paper ==> NOUN
# about ==> ADP
# ChatGPT.[28 ==> PROPN
# ] ==> PUNCT
#
#
#  ==> SPACE
# According ==> VERB
# to ==> ADP
# OpenAI ==> NOUN
# guest ==> NOUN
# researcher ==> NOUN
# Scott ==> PROPN
# Aaronson ==> PROPN
# , ==> PUNCT
# OpenAI ==> PROPN
# is ==> AUX
# working ==> VERB
# on ==> ADP
# a ==> DET
# tool ==> NOUN
# to ==> PART
# attempt ==> VERB
# to ==> PART
# watermark ==> VERB
# its ==> PRON
# text ==> NOUN
# generation ==> NOUN
# systems ==> NOUN
# so ==> SCONJ
# as ==> SCONJ
# to ==> PART
# combat ==> VERB
# bad ==> ADJ
# actors ==> NOUN
# using ==> VERB
# their ==> PRON
# services ==> NOUN
# for ==> ADP
# academic ==> ADJ
# plagiarism ==> NOUN
# or ==> CCONJ
# for ==> ADP
# spam.[29][30 ==> NOUN
# ] ==> PUNCT
# The ==> DET
# New ==> PROPN
# York ==> PROPN
# Times ==> PROPN
# relayed ==> VERB
# in ==> ADP
# December ==> PROPN
# 2022 ==> NUM
# that ==> SCONJ
# the ==> DET
# next ==> ADJ
# version ==> NOUN
# of ==> ADP
# GPT ==> PROPN
# , ==> PUNCT
# GPT-4 ==> PROPN
# , ==> PUNCT
# has ==> AUX
# been ==> AUX
# " ==> PUNCT
# rumored ==> VERB
# " ==> PUNCT
# to ==> PART
# be ==> AUX
# launched ==> VERB
# sometime ==> ADV
# in ==> ADP
# 2023.[17 ==> NUM
# ] ==> X
#
#
#  ==> SPACE
# Reception ==> NOUN
# and ==> CCONJ
# implications ==> NOUN
# Positive ==> ADJ
# reactions ==> NOUN
# ChatGPT ==> NOUN
# was ==> AUX
# met ==> VERB
# in ==> ADP
# December ==> PROPN
# 2022 ==> NUM
# with ==> ADP
# generally ==> ADV
# positive ==> ADJ
# reviews ==> NOUN
# ; ==> PUNCT
# The ==> DET
# New ==> PROPN
# York ==> PROPN
# Times ==> PROPN
# labeled ==> VERB
# it ==> PRON
# " ==> PUNCT
# the ==> DET
# best ==> ADJ
# artificial ==> ADJ
# intelligence ==> NOUN
# chatbot ==> PROPN
# ever ==> ADV
# released ==> VERB
# to ==> ADP
# the ==> DET
# general ==> ADJ
# public".[31 ==> NOUN
# ] ==> X
# Samantha ==> PROPN
# Lock ==> PROPN
# of ==> ADP
# The ==> DET
# Guardian ==> PROPN
# noted ==> VERB
# that ==> SCONJ
# it ==> PRON
# was ==> AUX
# able ==> ADJ
# to ==> PART
# generate ==> VERB
# " ==> PUNCT
# impressively ==> ADV
# detailed ==> ADJ
# " ==> PUNCT
# and ==> CCONJ
# " ==> PUNCT
# human ==> NOUN
# - ==> PUNCT
# like ==> ADJ
# " ==> PUNCT
# text.[32 ==> NOUN
# ] ==> PUNCT
# Technology ==> NOUN
# writer ==> NOUN
# Dan ==> PROPN
# Gillmor ==> PROPN
# used ==> VERB
# ChatGPT ==> NOUN
# on ==> ADP
# a ==> DET
# student ==> NOUN
# assignment ==> NOUN
# , ==> PUNCT
# and ==> CCONJ
# found ==> VERB
# its ==> PRON
# generated ==> VERB
# text ==> NOUN
# was ==> AUX
# on ==> ADP
# par ==> NOUN
# with ==> ADP
# what ==> PRON
# a ==> DET
# good ==> ADJ
# student ==> NOUN
# would ==> AUX
# deliver ==> VERB
# and ==> CCONJ
# opined ==> VERB
# that ==> SCONJ
# " ==> PUNCT
# academia ==> NOUN
# has ==> VERB
# some ==> DET
# very ==> ADV
# serious ==> ADJ
# issues ==> NOUN
# to ==> PART
# confront".[33 ==> VERB
# ] ==> PUNCT
# Alex ==> PROPN
# Kantrowitz ==> PROPN
# of ==> ADP
# Slate ==> PROPN
# magazine ==> NOUN
# lauded ==> VERB
# ChatGPT ==> PROPN
# 's ==> PART
# pushback ==> NOUN
# to ==> ADP
# questions ==> NOUN
# related ==> VERB
# to ==> ADP
# Nazi ==> PROPN
# Germany ==> PROPN
# , ==> PUNCT
# including ==> VERB
# the ==> DET
# claim ==> NOUN
# that ==> SCONJ
# Adolf ==> PROPN
# Hitler ==> PROPN
# built ==> VERB
# highways ==> NOUN
# in ==> ADP
# Germany ==> PROPN
# , ==> PUNCT
# which ==> PRON
# was ==> AUX
# met ==> VERB
# with ==> ADP
# information ==> NOUN
# regarding ==> VERB
# Nazi ==> PROPN
# Germany ==> PROPN
# 's ==> PART
# use ==> NOUN
# of ==> ADP
# forced ==> ADJ
# labor.[34 ==> NOUN
# ] ==> PUNCT
#
#
#  ==> SPACE
# In ==> ADP
# The ==> DET
# Atlantic ==> PROPN
# 's ==> PART
# " ==> PUNCT
# Breakthroughs ==> PROPN
# of ==> ADP
# the ==> DET
# Year ==> NOUN
# " ==> PUNCT
# for ==> ADP
# 2022 ==> NUM
# , ==> PUNCT
# Derek ==> PROPN
# Thompson ==> PROPN
# included ==> VERB
# ChatGPT ==> NOUN
# as ==> ADP
# part ==> NOUN
# of ==> ADP
# " ==> PUNCT
# the ==> DET
# generative ==> ADJ
# - ==> PUNCT
# AI ==> NOUN
# eruption ==> NOUN
# " ==> PUNCT
# that ==> PRON
# " ==> PUNCT
# may ==> AUX
# change ==> VERB
# our ==> PRON
# mind ==> NOUN
# about ==> ADP
# how ==> SCONJ
# we ==> PRON
# work ==> VERB
# , ==> PUNCT
# how ==> SCONJ
# we ==> PRON
# think ==> VERB
# , ==> PUNCT
# and ==> CCONJ
# what ==> PRON
# human ==> ADJ
# creativity ==> NOUN
# really ==> ADV
# is".[35 ==> ADJ
# ] ==> X
#
#
#  ==> SPACE
# Kelsey ==> PROPN
# Piper ==> PROPN
# of ==> ADP
# the ==> DET
# Vox ==> PROPN
# website ==> NOUN
# wrote ==> VERB
# that ==> SCONJ
# " ==> PUNCT
# ChatGPT ==> NOUN
# is ==> AUX
# the ==> DET
# general ==> ADJ
# public ==> NOUN
# 's ==> PART
# first ==> ADJ
# hands ==> NOUN
# - ==> PUNCT
# on ==> ADP
# introduction ==> NOUN
# to ==> ADP
# how ==> SCONJ
# powerful ==> ADJ
# modern ==> ADJ
# AI ==> PROPN
# has ==> AUX
# gotten ==> VERB
# , ==> PUNCT
# and ==> CCONJ
# as ==> ADP
# a ==> DET
# result ==> NOUN
# , ==> PUNCT
# many ==> ADJ
# of ==> ADP
# us ==> PRON
# are ==> AUX
# [ ==> X
# stunned ==> VERB
# ] ==> PUNCT
# " ==> PUNCT
# and ==> CCONJ
# that ==> DET
# ChatGPT ==> NOUN
# is ==> AUX
# " ==> PUNCT
# smart ==> ADJ
# enough ==> ADV
# to ==> PART
# be ==> AUX
# useful ==> ADJ
# despite ==> SCONJ
# its ==> PRON
# flaws".[36 ==> NOUN
# ] ==> PUNCT
# Paul ==> PROPN
# Graham ==> PROPN
# of ==> ADP
# Y ==> PROPN
# Combinator ==> PROPN
# tweeted ==> VERB
# that ==> SCONJ
# " ==> PUNCT
# The ==> DET
# striking ==> ADJ
# thing ==> NOUN
# about ==> ADP
# the ==> DET
# reaction ==> NOUN
# to ==> ADP
# ChatGPT ==> PROPN
# is ==> AUX
# not ==> PART
# just ==> ADV
# the ==> DET
# number ==> NOUN
# of ==> ADP
# people ==> NOUN
# who ==> PRON
# are ==> AUX
# blown ==> VERB
# away ==> ADV
# by ==> ADP
# it ==> PRON
# , ==> PUNCT
# but ==> CCONJ
# who ==> PRON
# they ==> PRON
# are ==> AUX
# . ==> PUNCT
# These ==> PRON
# are ==> AUX
# not ==> PART
# people ==> NOUN
# who ==> PRON
# get ==> AUX
# excited ==> VERB
# by ==> ADP
# every ==> DET
# shiny ==> ADJ
# new ==> ADJ
# thing ==> NOUN
# . ==> PUNCT
# Clearly ==> ADV
# , ==> PUNCT
# something ==> PRON
# big ==> ADJ
# is ==> AUX
# happening ==> VERB
# . ==> PUNCT
# "[37 ==> PUNCT
# ] ==> PUNCT
# Elon ==> PROPN
# Musk ==> PROPN
# wrote ==> VERB
# that ==> SCONJ
# " ==> PUNCT
# ChatGPT ==> NOUN
# is ==> AUX
# scary ==> ADJ
# good ==> NOUN
# . ==> PUNCT
# We ==> PRON
# are ==> AUX
# not ==> PART
# far ==> ADV
# from ==> ADP
# dangerously ==> ADV
# strong ==> ADJ
# AI".[36 ==> PROPN
# ] ==> PUNCT
# Musk ==> PROPN
# paused ==> VERB
# OpenAI ==> PROPN
# 's ==> PART
# access ==> NOUN
# to ==> ADP
# a ==> DET
# Twitter ==> PROPN
# database ==> NOUN
# pending ==> VERB
# a ==> DET
# better ==> ADJ
# understanding ==> NOUN
# of ==> ADP
# OpenAI ==> PROPN
# 's ==> PART
# plans ==> NOUN
# , ==> PUNCT
# stating ==> VERB
# that ==> SCONJ
# " ==> PUNCT
# OpenAI ==> NOUN
# was ==> AUX
# started ==> VERB
# as ==> ADP
# open ==> ADJ
# - ==> PUNCT
# source ==> NOUN
# and ==> CCONJ
# non ==> ADJ
# - ==> ADJ
# profit ==> NOUN
# . ==> PUNCT
# Neither ==> PRON
# is ==> AUX
# still ==> ADV
# true ==> ADJ
# . ==> PUNCT
# "[38][39 ==> SPACE
# ] ==> PUNCT
# Musk ==> PROPN
# had ==> AUX
# co ==> VERB
# - ==> VERB
# founded ==> VERB
# OpenAI ==> NOUN
# in ==> ADP
# 2015 ==> NUM
# , ==> PUNCT
# in ==> ADP
# part ==> NOUN
# to ==> PART
# address ==> VERB
# existential ==> ADJ
# risk ==> NOUN
# from ==> ADP
# artificial ==> ADJ
# intelligence ==> NOUN
# , ==> PUNCT
# but ==> CCONJ
# had ==> AUX
# resigned ==> VERB
# in ==> ADP
# 2018.[39 ==> NUM
# ] ==> X
#
#
#  ==> SPACE
# Google ==> PROPN
# CEO ==> PROPN
# Sundar ==> PROPN
# Pichai ==> PROPN
# upended ==> VERB
# the ==> DET
# work ==> NOUN
# of ==> ADP
# numerous ==> ADJ
# internal ==> ADJ
# groups ==> NOUN
# in ==> ADP
# response ==> NOUN
# to ==> ADP
# the ==> DET
# threat ==> NOUN
# of ==> ADP
# disruption ==> NOUN
# by ==> ADP
# ChatGPT.[40 ==> NOUN
# ] ==> PUNCT
# In ==> ADP
# December ==> PROPN
# 2022 ==> NUM
# , ==> PUNCT
# Google ==> PROPN
# internally ==> ADV
# expressed ==> VERB
# alarm ==> NOUN
# at ==> ADP
# the ==> DET
# unexpected ==> ADJ
# strength ==> NOUN
# of ==> ADP
# ChatGPT ==> NOUN
# and ==> CCONJ
# the ==> DET
# newly ==> ADV
# discovered ==> VERB
# potential ==> NOUN
# of ==> ADP
# large ==> ADJ
# language ==> NOUN
# models ==> NOUN
# to ==> PART
# disrupt ==> VERB
# the ==> DET
# search ==> NOUN
# engine ==> NOUN
# business ==> NOUN
# , ==> PUNCT
# and ==> CCONJ
# CEO ==> PROPN
# Sundar ==> PROPN
# Pichai ==> PROPN
# " ==> PUNCT
# upended ==> ADJ
# " ==> PUNCT
# and ==> CCONJ
# reassigned ==> VERB
# teams ==> NOUN
# within ==> ADP
# multiple ==> ADJ
# departments ==> NOUN
# to ==> PART
# aid ==> VERB
# in ==> ADP
# its ==> PRON
# artificial ==> ADJ
# intelligence ==> NOUN
# products ==> NOUN
# , ==> PUNCT
# according ==> VERB
# to ==> ADP
# The ==> DET
# New ==> PROPN
# York ==> PROPN
# Times.[40 ==> NOUN
# ] ==> PUNCT
# The ==> DET
# Information ==> NOUN
# reported ==> VERB
# on ==> ADP
# January ==> PROPN
# 3 ==> NUM
# , ==> PUNCT
# 2023 ==> NUM
# that ==> SCONJ
# Microsoft ==> PROPN
# Bing ==> PROPN
# was ==> AUX
# planning ==> VERB
# to ==> PART
# add ==> VERB
# optional ==> ADJ
# ChatGPT ==> ADJ
# functionality ==> NOUN
# into ==> ADP
# its ==> PRON
# public ==> ADJ
# search ==> NOUN
# engine ==> NOUN
# , ==> PUNCT
# possibly ==> ADV
# around ==> ADP
# March ==> PROPN
# 2023.[41][42 ==> NUM
# ] ==> X
#
#
#  ==> SPACE
# Stuart ==> PROPN
# Cobbe ==> PROPN
# , ==> PUNCT
# a ==> DET
# chartered ==> ADJ
# accountant ==> NOUN
# in ==> ADP
# England ==> PROPN
# & ==> CCONJ
# Wales ==> PROPN
# , ==> PUNCT
# decided ==> VERB
# to ==> ADP
# the ==> DET
# test ==> NOUN
# the ==> DET
# ChatGPT ==> PROPN
# chatbot ==> NOUN
# by ==> ADP
# entering ==> VERB
# questions ==> NOUN
# from ==> ADP
# a ==> DET
# sample ==> NOUN
# exam ==> NOUN
# paper ==> NOUN
# on ==> ADP
# the ==> DET
# ICAEW ==> ADJ
# website ==> NOUN
# and ==> CCONJ
# then ==> ADV
# entering ==> VERB
# its ==> PRON
# answers ==> NOUN
# back ==> ADV
# into ==> ADP
# the ==> DET
# online ==> ADJ
# test ==> NOUN
# . ==> PUNCT
# ChatGPT ==> PROPN
# scored ==> VERB
# 42 ==> NUM
# % ==> NOUN
# which ==> PRON
# , ==> PUNCT
# while ==> SCONJ
# below ==> ADP
# the ==> DET
# 55 ==> NUM
# % ==> NOUN
# pass ==> NOUN
# mark ==> NOUN
# , ==> PUNCT
# was ==> AUX
# considered ==> VERB
# a ==> DET
# reasonable ==> ADJ
# attempt ==> NOUN
# . ==> PUNCT

# %%
pos_count=doc1.count_by(spacy.attrs.POS)
pos_count
# Out:
# {96: 139,
#  97: 181,
#  92: 301,
#  85: 166,
#  103: 15,
#  87: 61,
#  86: 42,
#  100: 163,
#  84: 118,
#  90: 95,
#  94: 48,
#  95: 43,
#  89: 44,
#  98: 30,
#  101: 13,
#  93: 30}

# %%
from spacy import displacy
displacy.render(doc1,style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5f3d32f199fa4e38a5512b6d69b1efc6-0" class="displacy" width="226150" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">ioneer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Building,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">San</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Francisco,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">headquarters</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">OpenAI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Sam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Altman,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">CEO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">OpenAI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">ChatGPT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">fine-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">tuned</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">top</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">GPT-3.5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">supervised</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">well</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">reinforcement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">learning.[5]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">Both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">approache

# %%
options={'compact':'True','color':'blue'}


displacy.render(doc1,style='dep',options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="65d66ee558e0482cb084d8107efed254-0" class="displacy" width="193850" height="1037.0" direction="ltr" style="max-width: none; height: 1037.0px; color: blue; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">ioneer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Building,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">San</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Francisco,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">headquarters</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">OpenAI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Sam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Altman,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">CEO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">OpenAI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">ChatGPT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">fine-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">tuned</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">top</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">GPT-3.5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">supervised</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">well</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">reinforcement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">learning.[5]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">Both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="947.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">approaches</tspan>
#     <tspan class="displacy

# %%
doc2=pd.DataFrame(X, columns=['X'])
doc2
# Out:
#                                                     X
# 0   ioneer Building, San Francisco, headquarters o...
# 1   In the case of supervised learning, the model ...
# 2   In the reinforcement step, human trainers firs...
# 3   These rankings were used to create 'reward mod...
# 4   The models were trained in collaboration with ...
# 5   In addition, OpenAI continues to gather data f...
# 6   Users are allowed to upvote or downvote the re...
# 7   For example, it has the ability to write and d...
# 8   In one example, whereas InstructGPT accepts th...
# 9   OpenAI acknowledged that ChatGPT "sometimes wr...
# 10  This behavior is common to large language mode...
# 11  According to the BBC, as of December 2022 Chat...
# 12  In training ChatGPT, human reviewers preferred...
# 13  Training data also suffers from algorithmic bi...
# 14  In one instance, ChatGPT generated a rap indic...
# 15  The service was launched as initially free to ...
# 16  The service works best in English, but is also...
# 17  Unlike some other recent high-profile advances...
# 18  According to OpenAI guest researcher Scott Aar...
# 19  The New York Times relayed in December 2022 th...
# 20  Reception and implications Positive reactions ...
# 21  In The Atlantic's "Breakthroughs of the Year" ...
# 22  [stunned]" and that ChatGPT is "smart enough t...
# 23  These are not people who get excited by every ...
# 24               Clearly, something big is happening.
# 25  "[37] Elon Musk wrote that "ChatGPT is scary g...
# 26  We are not far from dangerously strong AI".[36...
# 27                             Neither is still true.
# 28  "[38][39] Musk had co-founded OpenAI in 2015, ...
# 29  Google CEO Sundar Pichai upended the work of n...
# 30  In December 2022, Google internally expressed ...
# 31  The Information reported on January 3, 2023 th...
# 32  ChatGPT scored 42% which, while below the 55% ...

# %%
X
# Out:
# [ioneer Building, San Francisco, headquarters of OpenAI
#
#  Sam Altman, CEO of OpenAI ChatGPT was fine-tuned on top of GPT-3.5 using supervised learning as well as reinforcement learning.[5] Both approaches used human trainers to improve the model's performance.,
#  In the case of supervised learning, the model was provided with conversations in which the trainers played both sides: the user and the AI assistant.,
#  In the reinforcement step, human trainers first ranked responses that the model had created in a previous conversation.,
#  These rankings were used to create 'reward models' that the model was further fine-tuned on using several iterations of Proximal Policy Optimization (PPO).[6][7] Proximal Policy Optimization algorithms present a cost-effective benefit to trust region policy optimization algorithms; they negate many of the computationally expensive operations with faster performance.[8][9],
#  The models were trained in collaboration with Microsoft on their Azure supercomputing infrastructure.
#  ,
#  In addition, OpenAI continues to gather data from ChatGPT users that could be used to further train and fine-tune ChatGPT.,
#  Users are allowed to upvote or downvote the responses they receive from ChatGPT; upon upvoting or downvoting, they can also fill out a text field with additional feedback.[10][11][12]
#
#  Features and limitations
#
#  Cropped screenshot of a conversation with ChatGPT, December 30, 2022 Although the core function of a chatbot is to mimic a human conversationalist, ChatGPT is versatile.,
#  For example, it has the ability to write and debug computer programs; to compose music, teleplays, fairy tales, and student essays; to answer test questions (sometimes, depending on the test, at a level above the average human test-taker);[13] to write poetry and song lyrics;[14] to emulate a Linux system; to simulate an entire chat room; to play games like tic-tac-toe; and to simulate an ATM.[15] ChatGPT's training data includes man pages and information about Internet phenomena and programming languages, such as bulletin board systems and the Python programming language.[15]
#
#  In comparison to its predecessor, InstructGPT, ChatGPT attempts to reduce harmful and deceitful responses.[16],
#  In one example, whereas InstructGPT accepts the premise of the prompt "Tell me about when Christopher Columbus came to the US in 2015" as being truthful, ChatGPT acknowledges the counterfactual nature of the question and frames its answer as a hypothetical consideration of what might happen if Columbus came to the U.S. in 2015, using information about Columbus' voyages and facts about the modern world – including modern perceptions of Columbus' actions.[6]
#
#  Unlike most chatbots, ChatGPT remembers previous prompts given to it in the same conversation; journalists have suggested that this will allow ChatGPT to be used as a personalized therapist.[17] To prevent offensive outputs from being presented to and produced from ChatGPT, queries are filtered through OpenAI's company-wide moderation API,[18][19] and potentially racist or sexist prompts are dismissed.[6][17]
#
#  ChatGPT suffers from multiple limitations.,
#  OpenAI acknowledged that ChatGPT "sometimes writes plausible-sounding but incorrect or nonsensical answers".[6],
#  This behavior is common to large language models and is called hallucination.[20] The reward model of ChatGPT, designed around human oversight, can be over-optimized and thus hinder performance, otherwise known as Goodhart's law.[21] ChatGPT has limited knowledge of events that occurred after 2021.,
#  According to the BBC, as of December 2022 ChatGPT is not allowed to "express political opinions or engage in political activism".[22] Yet, research suggests that ChatGPT exhibits a pro-environmental, left-libertarian orientation when prompted to take a stance on political statements from two established voting advice applications.[23],
#  In training ChatGPT, human reviewers preferred longer answers, irrespective of actual comprehension or factual content.[6],
#  Training data also suffers from algorithmic bias, which may be revealed when ChatGPT responds to prompts including descriptors of people.,
#  In one instance, ChatGPT generated a rap indicating that women and scientists of color were inferior to white and male scientists.[24][25]
#
#  Service ChatGPT was launched on November 30, 2022, by San Francisco-based OpenAI, the creator of DALL·E 2 and Whisper.,
#  The service was launched as initially free to the public, with plans to monetize the service later.[26] By December 4, OpenAI estimated ChatGPT already had over one million users.[10] CNBC wrote on December 15, 2022, that the service "still goes down from time to time".[27],
#  The service works best in English, but is also able to function in some other languages, to varying degrees of success.[14],
#  Unlike some other recent high-profile advances in AI, as of December 2022, there is no sign of an official peer-reviewed technical paper about ChatGPT.[28]
#  ,
#  According to OpenAI guest researcher Scott Aaronson, OpenAI is working on a tool to attempt to watermark its text generation systems so as to combat bad actors using their services for academic plagiarism or for spam.[29][30],
#  The New York Times relayed in December 2022 that the next version of GPT, GPT-4, has been "rumored" to be launched sometime in 2023.[17]
#  ,
#  Reception and implications Positive reactions ChatGPT was met in December 2022 with generally positive reviews; The New York Times labeled it "the best artificial intelligence chatbot ever released to the general public".[31] Samantha Lock of The Guardian noted that it was able to generate "impressively detailed" and "human-like" text.[32] Technology writer Dan Gillmor used ChatGPT on a student assignment, and found its generated text was on par with what a good student would deliver and opined that "academia has some very serious issues to confront".[33] Alex Kantrowitz of Slate magazine lauded ChatGPT's pushback to questions related to Nazi Germany, including the claim that Adolf Hitler built highways in Germany, which was met with information regarding Nazi Germany's use of forced labor.[34]
#  ,
#  In The Atlantic's "Breakthroughs of the Year" for 2022, Derek Thompson included ChatGPT as part of "the generative-AI eruption" that "may change our mind about how we work, how we think, and what human creativity really is".[35]
#
#  Kelsey Piper of the Vox website wrote that "ChatGPT is the general public's first hands-on introduction to how powerful modern AI has gotten, and as a result, many of us are,
#  [stunned]" and that ChatGPT is "smart enough to be useful despite its flaws".[36] Paul Graham of Y Combinator tweeted that "The striking thing about the reaction to ChatGPT is not just the number of people who are blown away by it, but who they are.,
#  These are not people who get excited by every shiny new thing.,
#  Clearly, something big is happening.,
#  "[37] Elon Musk wrote that "ChatGPT is scary good.,
#  We are not far from dangerously strong AI".[36] Musk paused OpenAI's access to a Twitter database pending a better understanding of OpenAI's plans, stating that "OpenAI was started as open-source and non-profit.,
#  Neither is still true.,
#  "[38][39] Musk had co-founded OpenAI in 2015, in part to address existential risk from artificial intelligence, but had resigned in 2018.[39]
#  ,
#  Google CEO Sundar Pichai upended the work of numerous internal groups in response to the threat of disruption by ChatGPT.[40],
#  In December 2022, Google internally expressed alarm at the unexpected strength of ChatGPT and the newly discovered potential of large language models to disrupt the search engine business, and CEO Sundar Pichai "upended" and reassigned teams within multiple departments to aid in its artificial intelligence products, according to The New York Times.[40],
#  The Information reported on January 3, 2023 that Microsoft Bing was planning to add optional ChatGPT functionality into its public search engine, possibly around March 2023.[41][42]
#
#  Stuart Cobbe, a chartered accountant in England & Wales, decided to the test the ChatGPT chatbot by entering questions from a sample exam paper on the ICAEW website and then entering its answers back into the online test.,
#  ChatGPT scored 42% which, while below the 55% pass mark, was considered a reasonable attempt.]

# %%
token=[]
for sent in nlp.pipe(doc2['Sentence']):
    if sent.has_annotation('DEP'):
        token.append([word.text for word in sent] )
token
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sentence'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 token=[]
# ----> 2 for sent in nlp.pipe(doc2['Sentence']):
#       3     if sent.has_annotation('DEP'):
#       4         token.append([word.text for word in sent] )
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Sentence'

# %%
#Converting into dataframe

token=[]
pos=[]
for sent in nlp.pipe(doc2['X']):
    if sent.has_annotation('DEP'):
        token.append([word.text for word in sent] )
        pos.append([word.pos_ for word in sent])
print(token)
print(pos)
# Out:
# [['ioneer', 'Building', ',', 'San', 'Francisco', ',', 'headquarters', 'of', 'OpenAI', '\n\n', 'Sam', 'Altman', ',', 'CEO', 'of', 'OpenAI', 'ChatGPT', 'was', 'fine', '-', 'tuned', 'on', 'top', 'of', 'GPT-3.5', 'using', 'supervised', 'learning', 'as', 'well', 'as', 'reinforcement', 'learning.[5', ']', 'Both', 'approaches', 'used', 'human', 'trainers', 'to', 'improve', 'the', 'model', "'s", 'performance', '.'], ['In', 'the', 'case', 'of', 'supervised', 'learning', ',', 'the', 'model', 'was', 'provided', 'with', 'conversations', 'in', 'which', 'the', 'trainers', 'played', 'both', 'sides', ':', 'the', 'user', 'and', 'the', 'AI', 'assistant', '.'], ['In', 'the', 'reinforcement', 'step', ',', 'human', 'trainers', 'first', 'ranked', 'responses', 'that', 'the', 'model', 'had', 'created', 'in', 'a', 'previous', 'conversation', '.'], ['These', 'rankings', 'were', 'used', 'to', 'create', "'", 'reward', 'models', "'", 'that', 'the', 'model', 'was', 'further', 'fine', '-', 'tuned', 'on', 'using', 'several', 'iterations', 'of', 'Proximal', 'Policy', 'Optimization', '(', 'PPO).[6][7', ']', 'Proximal', 'Policy', 'Optimization', 'algorithms', 'present', 'a', 'cost', '-', 'effective', 'benefit', 'to', 'trust', 'region', 'policy', 'optimization', 'algorithms', ';', 'they', 'negate', 'many', 'of', 'the', 'computationally', 'expensive', 'operations', 'with', 'faster', 'performance.[8][9', ']'], ['The', 'models', 'were', 'trained', 'in', 'collaboration', 'with', 'Microsoft', 'on', 'their', 'Azure', 'supercomputing', 'infrastructure', '.', '\n\n'], ['In', 'addition', ',', 'OpenAI', 'continues', 'to', 'gather', 'data', 'from', 'ChatGPT', 'users', 'that', 'could', 'be', 'used', 'to', 'further', 'train', 'and', 'fine', '-', 'tune', 'ChatGPT', '.'], ['Users', 'are', 'allowed', 'to', 'upvote', 'or', 'downvote', 'the', 'responses', 'they', 'receive', 'from', 'ChatGPT', ';', 'upon', 'upvoting', 'or', 'downvoting', ',', 'they', 'can', 'also', 'fill', 'out', 'a', 'text', 'field', 'with', 'additional', 'feedback.[10][11][12', ']', '\n\n', 'Features', 'and', 'limitations', '\n\n', 'Cropped', 'screenshot', 'of', 'a', 'conversation', 'with', 'ChatGPT', ',', 'December', '30', ',', '2022', 'Although', 'the', 'core', 'function', 'of', 'a', 'chatbot', 'is', 'to', 'mimic', 'a', 'human', 'conversationalist', ',', 'ChatGPT', 'is', 'versatile', '.'], ['For', 'example', ',', 'it', 'has', 'the', 'ability', 'to', 'write', 'and', 'debug', 'computer', 'programs', ';', 'to', 'compose', 'music', ',', 'teleplays', ',', 'fairy', 'tales', ',', 'and', 'student', 'essays', ';', 'to', 'answer', 'test', 'questions', '(', 'sometimes', ',', 'depending', 'on', 'the', 'test', ',', 'at', 'a', 'level', 'above', 'the', 'average', 'human', 'test', '-', 'taker);[13', ']', 'to', 'write', 'poetry', 'and', 'song', 'lyrics;[14', ']', 'to', 'emulate', 'a', 'Linux', 'system', ';', 'to', 'simulate', 'an', 'entire', 'chat', 'room', ';', 'to', 'play', 'games', 'like', 'tic', '-', 'tac', '-', 'toe', ';', 'and', 'to', 'simulate', 'an', 'ATM.[15', ']', 'ChatGPT', "'s", 'training', 'data', 'includes', 'man', 'pages', 'and', 'information', 'about', 'Internet', 'phenomena', 'and', 'programming', 'languages', ',', 'such', 'as', 'bulletin', 'board', 'systems', 'and', 'the', 'Python', 'programming', 'language.[15', ']', '\n\n', 'In', 'comparison', 'to', 'its', 'predecessor', ',', 'InstructGPT', ',', 'ChatGPT', 'attempts', 'to', 'reduce', 'harmful', 'and', 'deceitful', 'responses.[16', ']'], ['In', 'one', 'example', ',', 'whereas', 'InstructGPT', 'accepts', 'the', 'premise', 'of', 'the', 'prompt', '"', 'Tell', 'me', 'about', 'when', 'Christopher', 'Columbus', 'came', 'to', 'the', 'US', 'in', '2015', '"', 'as', 'being', 'truthful', ',', 'ChatGPT', 'acknowledges', 'the', 'counterfactual', 'nature', 'of', 'the', 'question', 'and', 'frames', 'its', 'answer', 'as', 'a', 'hypothetical', 'consideration', 'of', 'what', 'might', 'happen', 'if', 'Columbus', 'came', 'to', 'the', 'U.S.', 'in', '2015', ',', 'using', 'informa ...
# [['PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'NOUN', 'ADP', 'PROPN', 'SPACE', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'ADP', 'PROPN', 'PROPN', 'AUX', 'ADV', 'PUNCT', 'VERB', 'ADP', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADV', 'ADV', 'ADP', 'NOUN', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'PART', 'VERB', 'DET', 'NOUN', 'PART', 'NOUN', 'PUNCT'], ['ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'AUX', 'VERB', 'ADP', 'NOUN', 'ADP', 'PRON', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'CCONJ', 'DET', 'PROPN', 'NOUN', 'PUNCT'], ['ADP', 'DET', 'NOUN', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'ADV', 'VERB', 'NOUN', 'SCONJ', 'DET', 'NOUN', 'AUX', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT'], ['DET', 'NOUN', 'AUX', 'VERB', 'PART', 'VERB', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'SCONJ', 'DET', 'NOUN', 'AUX', 'ADV', 'ADV', 'PUNCT', 'VERB', 'ADP', 'VERB', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'PROPN', 'PROPN', 'PUNCT', 'NOUN', 'X', 'PROPN', 'PROPN', 'PROPN', 'NOUN', 'VERB', 'DET', 'NOUN', 'PUNCT', 'ADJ', 'NOUN', 'PART', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'PUNCT', 'PRON', 'VERB', 'ADJ', 'ADP', 'DET', 'ADV', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'PROPN', 'PUNCT'], ['DET', 'NOUN', 'AUX', 'VERB', 'ADP', 'NOUN', 'ADP', 'PROPN', 'ADP', 'PRON', 'PROPN', 'NOUN', 'NOUN', 'PUNCT', 'SPACE'], ['ADP', 'NOUN', 'PUNCT', 'PROPN', 'VERB', 'PART', 'VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'PRON', 'AUX', 'AUX', 'VERB', 'PART', 'ADV', 'VERB', 'CCONJ', 'ADJ', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT'], ['NOUN', 'AUX', 'VERB', 'PART', 'VERB', 'CCONJ', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'ADP', 'PROPN', 'PUNCT', 'SCONJ', 'VERB', 'CCONJ', 'ADJ', 'PUNCT', 'PRON', 'AUX', 'ADV', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'PUNCT', 'SPACE', 'PROPN', 'CCONJ', 'NOUN', 'SPACE', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'PROPN', 'NUM', 'PUNCT', 'NUM', 'SCONJ', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'AUX', 'PART', 'VERB', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'PROPN', 'AUX', 'ADJ', 'PUNCT'], ['ADP', 'NOUN', 'PUNCT', 'PRON', 'VERB', 'DET', 'NOUN', 'PART', 'VERB', 'CCONJ', 'VERB', 'NOUN', 'NOUN', 'PUNCT', 'PART', 'VERB', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'CCONJ', 'NOUN', 'NOUN', 'PUNCT', 'PART', 'VERB', 'NOUN', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'VERB', 'ADP', 'DET', 'NOUN', 'PUNCT', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'PUNCT', 'X', 'PUNCT', 'PART', 'VERB', 'NOUN', 'CCONJ', 'NOUN', 'X', 'X', 'PART', 'VERB', 'DET', 'PROPN', 'NOUN', 'PUNCT', 'PART', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', 'PUNCT', 'PART', 'VERB', 'NOUN', 'ADP', 'ADJ', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'CCONJ', 'PART', 'VERB', 'DET', 'PROPN', 'PUNCT', 'PROPN', 'PART', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'CCONJ', 'NOUN', 'NOUN', 'PUNCT', 'ADJ', 'ADP', 'PROPN', 'NOUN', 'NOUN', 'CCONJ', 'DET', 'PROPN', 'NOUN', 'NOUN', 'PUNCT', 'SPACE', 'ADP', 'NOUN', 'ADP', 'PRON', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'PART', 'VERB', 'ADJ', 'CCONJ', 'ADJ', 'PROPN', 'PUNCT'], ['ADP', 'NUM', 'NOUN', 'PUNCT', 'SCONJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT', 'VERB', 'PRON', 'ADP', 'SCONJ', 'PROPN', 'PROPN', 'VERB', 'ADP', 'DET', 'PROPN', 'ADP', 'NUM', 'PUNCT', 'ADP', 'AUX', 'ADJ', 'PUNCT', 'PROPN', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'CCONJ', 'VERB', 'PRON', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'PRON', 'AUX', 'VERB', 'SCONJ', 'PROPN', 'VERB', 'ADP', 'DET', 'PROPN', 'ADP', 'NUM', 'PUNCT', 'VERB', 'NOUN', 'ADP', 'PROPN', 'PART', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'NOUN', 'PUNCT', 'SPACE', 'ADP', 'ADJ', 'NOUN', 'PUNCT', 'PROPN', 'VERB', 'ADJ', 'NOUN', 'VERB', 'ADP', 'PRON', 'ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'NOUN', 'AUX', 'VERB', 'SCONJ', 'PRON', 'AUX', 'VERB', 'NOUN', 'PART', 'AUX', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'PART', 'VE ...

# %%
# Updating text_df

doc2['Token']=token
doc2['POS']=pos

# %%
doc2
# Out:
#                                                     X  \
# 0   ioneer Building, San Francisco, headquarters o...
# 1   In the case of supervised learning, the model ...
# 2   In the reinforcement step, human trainers firs...
# 3   These rankings were used to create 'reward mod...
# 4   The models were trained in collaboration with ...
# 5   In addition, OpenAI continues to gather data f...
# 6   Users are allowed to upvote or downvote the re...
# 7   For example, it has the ability to write and d...
# 8   In one example, whereas InstructGPT accepts th...
# 9   OpenAI acknowledged that ChatGPT "sometimes wr...
# 10  This behavior is common to large language mode...
# 11  According to the BBC, as of December 2022 Chat...
# 12  In training ChatGPT, human reviewers preferred...
# 13  Training data also suffers from algorithmic bi...
# 14  In one instance, ChatGPT generated a rap indic...
# 15  The service was launched as initially free to ...
# 16  The service works best in English, but is also...
# 17  Unlike some other recent high-profile advances...
# 18  According to OpenAI guest researcher Scott Aar...
# 19  The New York Times relayed in December 2022 th...
# 20  Reception and implications Positive reactions ...
# 21  In The Atlantic's "Breakthroughs of the Year" ...
# 22  [stunned]" and that ChatGPT is "smart enough t...
# 23  These are not people who get excited by every ...
# 24               Clearly, something big is happening.
# 25  "[37] Elon Musk wrote that "ChatGPT is scary g...
# 26  We are not far from dangerously strong AI".[36...
# 27                             Neither is still true.
# 28  "[38][39] Musk had co-founded OpenAI in 2015, ...
# 29  Google CEO Sundar Pichai upended the work of n...
# 30  In December 2022, Google internally expressed ...
# 31  The Information reported on January 3, 2023 th...
# 32  ChatGPT scored 42% which, while below the 55% ...
#
#                                                 Token  \
# 0   [ioneer, Building, ,, San, Francisco, ,, headq...
# 1   [In, the, case, of, supervised, learning, ,, t...
# 2   [In, the, reinforcement, step, ,, human, train...
# 3   [These, rankings, were, used, to, create, ', r...
# 4   [The, models, were, trained, in, collaboration...
# 5   [In, addition, ,, OpenAI, continues, to, gathe...
# 6   [Users, are, allowed, to, upvote, or, downvote...
# 7   [For, example, ,, it, has, the, ability, to, w...
# 8   [In, one, example, ,, whereas, InstructGPT, ac...
# 9   [OpenAI, acknowledged, that, ChatGPT, ", somet...
# 10  [This, behavior, is, common, to, large, langua...
# 11  [According, to, the, BBC, ,, as, of, December,...
# 12  [In, training, ChatGPT, ,, human, reviewers, p...
# 13  [Training, data, also, suffers, from, algorith...
# 14  [In, one, instance, ,, ChatGPT, generated, a, ...
# 15  [The, service, was, launched, as, initially, f...
# 16  [The, service, works, best, in, English, ,, bu...
# 17  [Unlike, some, other, recent, high, -, profile...
# 18  [According, to, OpenAI, guest, researcher, Sco...
# 19  [The, New, York, Times, relayed, in, December,...
# 20  [Reception, and, implications, Positive, react...
# 21  [In, The, Atlantic, 's, ", Breakthroughs, of, ...
# 22  [[, stunned, ], ", and, that, ChatGPT, is, ", ...
# 23  [These, are, not, people, who, get, excited, b...
# 24     [Clearly, ,, something, big, is, happening, .]
# 25  [", [, 37, ], Elon, Musk, wrote, that, ", Chat...
# 26  [We, are, not, far, from, dangerously, strong,...
# 27                      [Neither, is, still, true, .]
# 28  [", [, 38][39, ], Musk, had, co, -, founded, O...
# 29  [Google, CEO, Sundar, Pichai, upended, the, wo...
# 30  [In, December, 2022, ,, Google, internally, ex...
# 31  [The, Information, reported, on, January, 3, ,...
# 32  [ChatGPT, scored, 42, %, which, ,, while, belo...
#
#                                                   POS
# 0   [PROPN, PROPN, PUNCT, PROPN, PROPN, PUNCT, NOU...
# 1   [ADP, DET, NOUN, ADP, ADJ, NOUN, PUNCT, DET, N...
# 2   [ADP, DET, NOUN, NOUN, PUNCT, ADJ, NOUN, ADV, ...
# 3   [DET, NOUN, AUX, VERB, PART, VERB, PUNCT, NOUN...
# 4   [DET, NOUN, AUX, VERB, ADP, NOUN, ADP, PROPN, ...
# 5   [ADP, NOUN, PUNCT, PROPN, VERB, PART, VERB, NO...
# 6   [NOUN, AUX, VERB, PART, VERB, CCONJ, VERB, DET...
# 7   [ADP, NOUN, PUNCT, PRON, VERB, DET, NOUN, PART...
# 8   [ADP, NUM, NOUN, PUNCT, SCONJ, NOUN, VERB, DET...
# 9   [PROPN, VERB, SCONJ, NOUN, PUNCT, ADV, VERB, A...
# 10  [DET, NOUN, AUX, ADJ, ADP, ADJ, NOUN, NOUN, CC...
# 11  [VERB, ADP, DET, PROPN, PUNCT, ADP, ADP, PROPN...
# 12  [ADP, VERB, NOUN, PUNCT, ADJ, NOUN, VERB, ADJ,...
# 13  [NOUN, NOUN, ADV, VERB, ADP, ADJ, NOUN, PUNCT,...
# 14  [ADP, NUM, NOUN, PUNCT, PROPN, VERB, DET, NOUN...
# 15  [DET, NOUN, AUX, VERB, ADP, ADV, ADJ, ADP, DET...
# 16  [DET, NOUN, VERB, ADV, ADP, PROPN, PUNCT, CCON...
# 17  [ADP, DET, ADJ, ADJ, ADJ, PUNCT, NOUN, NOUN, A...
# 18  [VERB, ADP, NOUN, NOUN, NOUN, PROPN, PROPN, PU...
# 19  [DET, PROPN, PROPN, PROPN, VERB, ADP, PROPN, N...
# 20  [NOUN, CCONJ, NOUN, ADJ, NOUN, NOUN, AUX, VERB...
# 21  [ADP, DET, PROPN, PART, PUNCT, PROPN, ADP, DET...
# 22  [X, VERB, PUNCT, PUNCT, CCONJ, DET, NOUN, AUX,...
# 23  [PRON, AUX, PART, NOUN, PRON, AUX, VERB, ADP, ...
# 24          [ADV, PUNCT, PRON, ADJ, AUX, VERB, PUNCT]
# 25  [PUNCT, X, NUM, PUNCT, PROPN, PROPN, VERB, SCO...
# 26  [PRON, AUX, PART, ADV, ADP, ADV, ADJ, PROPN, P...
# 27                      [CCONJ, AUX, ADV, ADJ, PUNCT]
# 28  [PUNCT, X, X, X, PROPN, AUX, VERB, VERB, VERB,...
# 29  [PROPN, PROPN, PROPN, PROPN, VERB, DET, NOUN, ...
# 30  [ADP, PROPN, NUM, PUNCT, PROPN, ADV, VERB, NOU...
# 31  [DET, PROPN, VERB, ADP, PROPN, NUM, PUNCT, NUM...
# 32  [PROPN, VERB, NUM, NOUN, PRON, PUNCT, SCONJ, A...

# %%
## Noun chunks

for chunk in doc1.noun_chunks:
    print(chunk.text, '==>',chunk.label_)
# Out:
# ioneer Building ==> NP
# San Francisco ==> NP
# headquarters ==> NP
# OpenAI
#
# Sam Altman ==> NP
# CEO ==> NP
# OpenAI ChatGPT ==> NP
# top ==> NP
# GPT-3.5 ==> NP
# supervised learning ==> NP
# Both approaches ==> NP
# human trainers ==> NP
# the model's performance ==> NP
# the case ==> NP
# supervised learning ==> NP
# the model ==> NP
# conversations ==> NP
# which ==> NP
# the trainers ==> NP
# both sides ==> NP
# the user ==> NP
# the AI assistant ==> NP
# the reinforcement step ==> NP
# human trainers ==> NP
# responses ==> NP
# the model ==> NP
# a previous conversation ==> NP
# These rankings ==> NP
# 'reward models ==> NP
# the model ==> NP
# several iterations ==> NP
# PPO).[6][7 ==> NP
# a cost-effective benefit ==> NP
# region policy optimization algorithms ==> NP
# they ==> NP
# the computationally expensive operations ==> NP
# faster performance.[8][9 ==> NP
# The models ==> NP
# collaboration ==> NP
# Microsoft ==> NP
# their Azure supercomputing infrastructure ==> NP
# addition ==> NP
# OpenAI ==> NP
# data ==> NP
# ChatGPT users ==> NP
# that ==> NP
# Users ==> NP
# the responses ==> NP
# they ==> NP
# ChatGPT ==> NP
# they ==> NP
# a text field ==> NP
# additional feedback.[10][11][12 ==> NP
# Features ==> NP
# limitations ==> NP
# screenshot ==> NP
# a conversation ==> NP
# ChatGPT ==> NP
# the core function ==> NP
# a chatbot ==> NP
# a human conversationalist ==> NP
# ChatGPT ==> NP
# example ==> NP
# it ==> NP
# the ability ==> NP
# computer programs ==> NP
# music ==> NP
# teleplays ==> NP
# fairy tales ==> NP
# student essays ==> NP
# test questions ==> NP
# the test ==> NP
# a level ==> NP
# poetry ==> NP
# song ==> NP
# a Linux system ==> NP
# an entire chat room ==> NP
# games ==> NP
# tic-tac-toe ==> NP
# an ATM.[15 ==> NP
# ChatGPT's training data ==> NP
# man pages ==> NP
# information ==> NP
# Internet phenomena ==> NP
# programming languages ==> NP
# bulletin board systems ==> NP
# the Python programming language.[15 ==> NP
# comparison ==> NP
# its predecessor ==> NP
# InstructGPT ==> NP
# ChatGPT attempts ==> NP
# harmful and deceitful responses.[16 ==> NP
# one example ==> NP
# InstructGPT ==> NP
# the premise ==> NP
# the prompt ==> NP
# me ==> NP
# Christopher Columbus ==> NP
# the US ==> NP
# ChatGPT ==> NP
# the counterfactual nature ==> NP
# the question ==> NP
# its answer ==> NP
# a hypothetical consideration ==> NP
# what ==> NP
# Columbus ==> NP
# the U.S. ==> NP
# information ==> NP
# Columbus' voyages ==> NP
# facts ==> NP
# the modern world ==> NP
# modern perceptions ==> NP
# Columbus ==> NP
# actions.[6 ==> NP
# most chatbots ==> NP
# ChatGPT ==> NP
# previous prompts ==> NP
# it ==> NP
# the same conversation ==> NP
# journalists ==> NP
# this ==> NP
# ChatGPT ==> NP
# a personalized therapist.[17 ==> NP
# offensive outputs ==> NP
# ChatGPT ==> NP
# queries ==> NP
# OpenAI's company-wide moderation API,[18][19 ==> NP
# potentially racist or sexist prompts ==> NP
# dismissed.[6][17 ==> NP
# multiple limitations ==> NP
# OpenAI ==> NP
# ChatGPT ==> NP
# This behavior ==> NP
# large language models ==> NP
# hallucination.[20 ==> NP
# The reward model ==> NP
# ChatGPT ==> NP
# human oversight ==> NP
# over-optimized and thus hinder performance ==> NP
# Goodhart's law.[21 ==> NP
# ChatGPT ==> NP
# knowledge ==> NP
# events ==> NP
# that ==> NP
# the BBC ==> NP
# December 2022 ChatGPT ==> NP
# political opinions ==> NP
# political activism".[22 ==> NP
# research ==> NP
# ChatGPT ==> NP
# a pro-environmental, left-libertarian orientation ==> NP
# a stance ==> NP
# political statements ==> NP
# two established voting advice ==> NP
# applications.[23 ==> NP
# ChatGPT ==> NP
# human reviewers ==> NP
# longer answers ==> NP
# actual comprehension ==> NP
# factual content.[6 ==> NP
# Training data ==> NP
# algorithmic bias ==> NP
# which ==> NP
# ChatGPT ==> NP
# prompts ==> NP
# descriptors ==> NP
# people ==> NP
# one instance ==> NP
# ChatGPT ==> NP
# a rap ==> NP
# women ==> NP
# scientists ==> NP
# color ==> NP
# white and male scientists.[24][25 ==> NP
# Service ChatGPT ==> NP
# November ==> NP
# San Francisco-based OpenAI ==> NP
# the creator ==> NP
# DALL·E ==> NP
# Whisper ==> NP
# The service ==> NP
# the public ==> NP
# plans ==> NP
# the service later.[26 ==> NP
# December ==> NP
# OpenAI ==> NP
# over one million users.[10 ==> NP
# CNBC ==> NP
# December ==> NP
# the service ==> NP
# time ==> NP
# time".[27 ==> NP
# The service ==> NP
# English ==> NP
# some other languages ==> NP
# varying degrees ==> NP
# success.[14 ==> NP
# some other recent high-profile advances ==> NP
# AI ==> NP
# December ==> NP
# no sign ==> NP
# an official peer-reviewed technical paper ==> NP
# ChatGPT.[28 ==> NP
# OpenAI guest researcher Scott Aaronson ==> NP
# OpenAI ==> NP
# a tool ==> NP
# its text generation systems ==> NP
# bad actors ==> NP
# their services ==> NP
# academic plagiarism ==> NP
# spam.[29][30 ==> NP
# The New York Times ==> NP
# December ==> NP
# the next version ==> NP
# GPT ==> NP
# GPT-4 ==> NP
# Reception and implications Positive reactions ChatGPT ==> NP
# December ==> NP
# generally positive reviews ==> NP
# The New York Times ==> NP
# it ==> NP
# "the best artificial intelligence chatbot ==> NP
# the general public".[31 ==> NP
# Samantha Lock ==> NP
# The Guardian ==> NP
# it ==> NP
# "human-like" text.[32] Technology writer Dan Gillmor ==> NP
# ChatGPT ==> NP
# a student assignment ==> NP
# its generated text ==> NP
# par ==> NP
# what ==> NP
# a good student ==> NP
# academia ==> NP
# some very serious issues ==> NP
# Slate ==> NP
# ChatGPT's pushback ==> NP
# questions ==> NP
# Nazi Germany ==> NP
# the claim ==> NP
# Adolf Hitler ==> NP
# highways ==> NP
# Germany ==> NP
# which ==> NP
# information ==> NP
# Nazi Germany's use ==> NP
# forced labor.[34 ==> NP
# The Atlantic's "Breakthroughs ==> NP
# the Year ==> NP
# Derek Thompson ==> NP
# ChatGPT ==> NP
# part ==> NP
# "the generative-AI eruption ==> NP
# that ==> NP
# our mind ==> NP
# we ==> NP
# we ==> NP
# what human creativity ==> NP
# Kelsey Piper ==> NP
# the Vox website ==> NP
# ChatGPT ==> NP
# the general public's first hands-on introduction ==> NP
# modern AI ==> NP
# a result ==> NP
# us ==> NP
# that ChatGPT ==> NP
# its flaws".[36 ==> NP
# Paul Graham ==> NP
# Y Combinator ==> NP
# The striking thing ==> NP
# the reaction ==> NP
# ChatGPT ==> NP
# just the number ==> NP
# people ==> NP
# who ==> NP
# it ==> NP
# who ==> NP
# they ==> NP
# These ==> NP
# people ==> NP
# who ==> NP
# every shiny new thing ==> NP
# something ==> NP
# Elon Musk ==> NP
# ChatGPT ==> NP
# We ==> NP
# dangerously strong AI".[36 ==> NP
# Musk ==> NP
# OpenAI's access ==> NP
# a Twitter database ==> NP
# a better understanding ==> NP
# OpenAI's plans ==> NP
# OpenAI ==> NP
# open-source ==> NP
# profit ==> NP
# Neither ==> NP
# Musk ==> NP
# -founded OpenAI ==> NP
# part ==> NP
# existential risk ==> NP
# artificial intelligence ==> NP
# Google CEO Sundar Pichai ==> NP
# the work ==> NP
# numerous internal groups ==> NP
# response ==> NP
# the threat ==> NP
# disruption ==> NP
# ChatGPT.[40 ==> NP
# December ==> NP
# Google ==> NP
# alarm ==> NP
# the unexpected strength ==> NP
# ChatGPT ==> NP
# the newly discovered potential ==> NP
# large language models ==> NP
# the search engine business ==> NP
# CEO Sundar Pichai ==> NP
# teams ==> NP
# multiple departments ==> NP
# its artificial intelligence products ==> NP
# The New York Times.[40 ==> NP
# The Information ==> NP
# January ==> NP
# Microsoft Bing ==> NP
# optional ChatGPT functionality ==> NP
# its public search engine ==> NP
# March ==> NP
# Stuart Cobbe ==> NP
# a chartered accountant ==> NP
# England ==> NP
# Wales ==> NP
# the test ==> NP
# the ChatGPT chatbot ==> NP
# questions ==> NP
# a sample exam paper ==> NP
# the ICAEW website ==> NP
# its answers ==> NP
# the online test ==> NP
# ChatGPT ==> NP
# 42% ==> NP
# which ==> NP
# the 55% pass mark ==> NP
# a reasonable attempt ==> NP

# %%
ent_list2=[]
for ent in doc1.ents:
    print(ent.text,'==>',ent.label_)
    ent_list2.append(ent.label_)
# Out:
# Building ==> GPE
# San Francisco ==> GPE
# OpenAI
#
# Sam Altman ==> ORG
# OpenAI ChatGPT ==> ORG
# AI ==> ORG
# first ==> ORDINAL
# Proximal Policy Optimization ==> ORG
# Microsoft ==> ORG
# OpenAI ==> GPE
# feedback.[10][11][12 ==> CARDINAL
# ChatGPT ==> ORG
# December 30, 2022 ==> DATE
# ChatGPT ==> ORG
# Python ==> GPE
# InstructGPT ==> ORG
# one ==> CARDINAL
# InstructGPT ==> ORG
# Christopher Columbus ==> PERSON
# US ==> GPE
# 2015 ==> DATE
# Columbus ==> GPE
# U.S. ==> GPE
# 2015 ==> DATE
# Columbus ==> GPE
# Columbus ==> GPE
# OpenAI ==> GPE
# OpenAI ==> GPE
# Goodhart ==> ORG
# 2021 ==> DATE
# BBC ==> ORG
# December 2022 ==> DATE
# two ==> CARDINAL
# one ==> CARDINAL
# November 30, 2022 ==> DATE
# San Francisco ==> GPE
# OpenAI ==> GPE
# 2 ==> CARDINAL
# Whisper ==> PERSON
# December 4 ==> DATE
# OpenAI ==> GPE
# one million ==> CARDINAL
# CNBC ==> ORG
# December 15, 2022 ==> DATE
# time".[27 ==> ORG
# English ==> LANGUAGE
# AI ==> GPE
# December 2022 ==> DATE
# OpenAI ==> GPE
# Scott Aaronson ==> PERSON
# OpenAI ==> GPE
# The New York Times ==> ORG
# December 2022 ==> DATE
# GPT ==> ORG
# GPT-4 ==> PERSON
# 2023.[17 ==> CARDINAL
# Positive ==> DATE
# December 2022 ==> DATE
# The New York Times ==> ORG
# Guardian ==> ORG
# Dan Gillmor ==> PERSON
# Alex Kantrowitz ==> PERSON
# Slate ==> ORG
# ChatGPT ==> ORG
# Nazi Germany ==> GPE
# Hitler ==> PERSON
# Germany ==> GPE
# Nazi Germany's ==> ORG
# Atlantic ==> LOC
# Breakthroughs of the Year ==> ORG
# 2022 ==> DATE
# Derek Thompson ==> PERSON
# AI ==> ORG
# Vox ==> ORG
# first ==> ORDINAL
# AI ==> ORG
# Paul Graham ==> PERSON
# Elon Musk ==> WORK_OF_ART
# OpenAI ==> GPE
# Twitter ==> PRODUCT
# OpenAI ==> GPE
# OpenAI ==> GPE
# OpenAI ==> GPE
# 2015 ==> DATE
# 2018.[39 ==> CARDINAL
# Sundar Pichai ==> PERSON
# December 2022 ==> DATE
# Google ==> ORG
# Sundar Pichai ==> PERSON
# New York ==> GPE
# January 3, 2023 ==> DATE
# Microsoft Bing ==> PERSON
# around March 2023.[41][42 ==> DATE
# Stuart Cobbe ==> PERSON
# England & Wales ==> ORG
# ICAEW ==> ORG
# ChatGPT ==> ORG
# 42% ==> PERCENT
# the 55% ==> PERCENT

# %%
ent_list2
# Out:
# ['GPE',
#  'GPE',
#  'ORG',
#  'ORG',
#  'ORG',
#  'ORDINAL',
#  'ORG',
#  'ORG',
#  'GPE',
#  'CARDINAL',
#  'ORG',
#  'DATE',
#  'ORG',
#  'GPE',
#  'ORG',
#  'CARDINAL',
#  'ORG',
#  'PERSON',
#  'GPE',
#  'DATE',
#  'GPE',
#  'GPE',
#  'DATE',
#  'GPE',
#  'GPE',
#  'GPE',
#  'GPE',
#  'ORG',
#  'DATE',
#  'ORG',
#  'DATE',
#  'CARDINAL',
#  'CARDINAL',
#  'DATE',
#  'GPE',
#  'GPE',
#  'CARDINAL',
#  'PERSON',
#  'DATE',
#  'GPE',
#  'CARDINAL',
#  'ORG',
#  'DATE',
#  'ORG',
#  'LANGUAGE',
#  'GPE',
#  'DATE',
#  'GPE',
#  'PERSON',
#  'GPE',
#  'ORG',
#  'DATE',
#  'ORG',
#  'PERSON',
#  'CARDINAL',
#  'DATE',
#  'DATE',
#  'ORG',
#  'ORG',
#  'PERSON',
#  'PERSON',
#  'ORG',
#  'ORG',
#  'GPE',
#  'PERSON',
#  'GPE',
#  'ORG',
#  'LOC',
#  'ORG',
#  'DATE',
#  'PERSON',
#  'ORG',
#  'ORG',
#  'ORDINAL',
#  'ORG',
#  'PERSON',
#  'WORK_OF_ART',
#  'GPE',
#  'PRODUCT',
#  'GPE',
#  'GPE',
#  'GPE',
#  'DATE',
#  'CARDINAL',
#  'PERSON',
#  'DATE',
#  'ORG',
#  'PERSON',
#  'GPE',
#  'DATE',
#  'PERSON',
#  'DATE',
#  'PERSON',
#  'ORG',
#  'ORG',
#  'ORG',
#  'PERCENT',
#  'PERCENT']

# %%
ent_list=[(ent.text,ent.label_) for ent in doc1.ents]

# %%
ent_list
# Out:
# [('Building', 'GPE'),
#  ('San Francisco', 'GPE'),
#  ('OpenAI\n\nSam Altman', 'ORG'),
#  ('OpenAI ChatGPT', 'ORG'),
#  ('AI', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('Proximal Policy Optimization', 'ORG'),
#  ('Microsoft', 'ORG'),
#  ('OpenAI', 'GPE'),
#  ('feedback.[10][11][12', 'CARDINAL'),
#  ('ChatGPT', 'ORG'),
#  ('December 30, 2022', 'DATE'),
#  ('ChatGPT', 'ORG'),
#  ('Python', 'GPE'),
#  ('InstructGPT', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('InstructGPT', 'ORG'),
#  ('Christopher Columbus', 'PERSON'),
#  ('US', 'GPE'),
#  ('2015', 'DATE'),
#  ('Columbus', 'GPE'),
#  ('U.S.', 'GPE'),
#  ('2015', 'DATE'),
#  ('Columbus', 'GPE'),
#  ('Columbus', 'GPE'),
#  ('OpenAI', 'GPE'),
#  ('OpenAI', 'GPE'),
#  ('Goodhart', 'ORG'),
#  ('2021', 'DATE'),
#  ('BBC', 'ORG'),
#  ('December 2022', 'DATE'),
#  ('two', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('November 30, 2022', 'DATE'),
#  ('San Francisco', 'GPE'),
#  ('OpenAI', 'GPE'),
#  ('2', 'CARDINAL'),
#  ('Whisper', 'PERSON'),
#  ('December 4', 'DATE'),
#  ('OpenAI', 'GPE'),
#  ('one million', 'CARDINAL'),
#  ('CNBC', 'ORG'),
#  ('December 15, 2022', 'DATE'),
#  ('time".[27', 'ORG'),
#  ('English', 'LANGUAGE'),
#  ('AI', 'GPE'),
#  ('December 2022', 'DATE'),
#  ('OpenAI', 'GPE'),
#  ('Scott Aaronson', 'PERSON'),
#  ('OpenAI', 'GPE'),
#  ('The New York Times', 'ORG'),
#  ('December 2022', 'DATE'),
#  ('GPT', 'ORG'),
#  ('GPT-4', 'PERSON'),
#  ('2023.[17', 'CARDINAL'),
#  ('Positive', 'DATE'),
#  ('December 2022', 'DATE'),
#  ('The New York Times', 'ORG'),
#  ('Guardian', 'ORG'),
#  ('Dan Gillmor', 'PERSON'),
#  ('Alex Kantrowitz', 'PERSON'),
#  ('Slate', 'ORG'),
#  ('ChatGPT', 'ORG'),
#  ('Nazi Germany', 'GPE'),
#  ('Hitler', 'PERSON'),
#  ('Germany', 'GPE'),
#  ("Nazi Germany's", 'ORG'),
#  ('Atlantic', 'LOC'),
#  ('Breakthroughs of the Year', 'ORG'),
#  ('2022', 'DATE'),
#  ('Derek Thompson', 'PERSON'),
#  ('AI', 'ORG'),
#  ('Vox', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('AI', 'ORG'),
#  ('Paul Graham', 'PERSON'),
#  ('Elon Musk', 'WORK_OF_ART'),
#  ('OpenAI', 'GPE'),
#  ('Twitter', 'PRODUCT'),
#  ('OpenAI', 'GPE'),
#  ('OpenAI', 'GPE'),
#  ('OpenAI', 'GPE'),
#  ('2015', 'DATE'),
#  ('2018.[39', 'CARDINAL'),
#  ('Sundar Pichai', 'PERSON'),
#  ('December 2022', 'DATE'),
#  ('Google', 'ORG'),
#  ('Sundar Pichai', 'PERSON'),
#  ('New York', 'GPE'),
#  ('January 3, 2023', 'DATE'),
#  ('Microsoft Bing', 'PERSON'),
#  ('around March 2023.[41][42', 'DATE'),
#  ('Stuart Cobbe', 'PERSON'),
#  ('England & Wales', 'ORG'),
#  ('ICAEW', 'ORG'),
#  ('ChatGPT', 'ORG'),
#  ('42%', 'PERCENT'),
#  ('the 55%', 'PERCENT')]

# %%
ent_list1=[]
for ent in doc1.ents:
    ent_list1.append(ent.label_)
print(ent_list1)
# Out:
# ['GPE', 'GPE', 'ORG', 'ORG', 'ORG', 'ORDINAL', 'ORG', 'ORG', 'GPE', 'CARDINAL', 'ORG', 'DATE', 'ORG', 'GPE', 'ORG', 'CARDINAL', 'ORG', 'PERSON', 'GPE', 'DATE', 'GPE', 'GPE', 'DATE', 'GPE', 'GPE', 'GPE', 'GPE', 'ORG', 'DATE', 'ORG', 'DATE', 'CARDINAL', 'CARDINAL', 'DATE', 'GPE', 'GPE', 'CARDINAL', 'PERSON', 'DATE', 'GPE', 'CARDINAL', 'ORG', 'DATE', 'ORG', 'LANGUAGE', 'GPE', 'DATE', 'GPE', 'PERSON', 'GPE', 'ORG', 'DATE', 'ORG', 'PERSON', 'CARDINAL', 'DATE', 'DATE', 'ORG', 'ORG', 'PERSON', 'PERSON', 'ORG', 'ORG', 'GPE', 'PERSON', 'GPE', 'ORG', 'LOC', 'ORG', 'DATE', 'PERSON', 'ORG', 'ORG', 'ORDINAL', 'ORG', 'PERSON', 'WORK_OF_ART', 'GPE', 'PRODUCT', 'GPE', 'GPE', 'GPE', 'DATE', 'CARDINAL', 'PERSON', 'DATE', 'ORG', 'PERSON', 'GPE', 'DATE', 'PERSON', 'DATE', 'PERSON', 'ORG', 'ORG', 'ORG', 'PERCENT', 'PERCENT']

# %%
from collections import Counter
Counter(ent_list1)
# Out:
# Counter({'GPE': 24,
#          'ORG': 28,
#          'ORDINAL': 2,
#          'CARDINAL': 8,
#          'DATE': 17,
#          'PERSON': 13,
#          'LANGUAGE': 1,
#          'LOC': 1,
#          'WORK_OF_ART': 1,
#          'PRODUCT': 1,
#          'PERCENT': 2})

# %%
most_ent=[]
for ent in doc1.ents:
    most_ent.append(ent.text)
print(most_ent)
# Out:
# ['Building', 'San Francisco', 'OpenAI\n\nSam Altman', 'OpenAI ChatGPT', 'AI', 'first', 'Proximal Policy Optimization', 'Microsoft', 'OpenAI', 'feedback.[10][11][12', 'ChatGPT', 'December 30, 2022', 'ChatGPT', 'Python', 'InstructGPT', 'one', 'InstructGPT', 'Christopher Columbus', 'US', '2015', 'Columbus', 'U.S.', '2015', 'Columbus', 'Columbus', 'OpenAI', 'OpenAI', 'Goodhart', '2021', 'BBC', 'December 2022', 'two', 'one', 'November 30, 2022', 'San Francisco', 'OpenAI', '2', 'Whisper', 'December 4', 'OpenAI', 'one million', 'CNBC', 'December 15, 2022', 'time".[27', 'English', 'AI', 'December 2022', 'OpenAI', 'Scott Aaronson', 'OpenAI', 'The New York Times', 'December 2022', 'GPT', 'GPT-4', '2023.[17', 'Positive', 'December 2022', 'The New York Times', 'Guardian', 'Dan Gillmor', 'Alex Kantrowitz', 'Slate', 'ChatGPT', 'Nazi Germany', 'Hitler', 'Germany', "Nazi Germany's", 'Atlantic', 'Breakthroughs of the Year', '2022', 'Derek Thompson', 'AI', 'Vox', 'first', 'AI', 'Paul Graham', 'Elon Musk', 'OpenAI', 'Twitter', 'OpenAI', 'OpenAI', 'OpenAI', '2015', '2018.[39', 'Sundar Pichai', 'December 2022', 'Google', 'Sundar Pichai', 'New York', 'January 3, 2023', 'Microsoft Bing', 'around March 2023.[41][42', 'Stuart Cobbe', 'England & Wales', 'ICAEW', 'ChatGPT', '42%', 'the 55%']

# %%
# Most common

Counter(most_ent).most_common()
# Out:
# [('OpenAI', 11),
#  ('December 2022', 5),
#  ('AI', 4),
#  ('ChatGPT', 4),
#  ('2015', 3),
#  ('Columbus', 3),
#  ('San Francisco', 2),
#  ('first', 2),
#  ('InstructGPT', 2),
#  ('one', 2),
#  ('The New York Times', 2),
#  ('Sundar Pichai', 2),
#  ('Building', 1),
#  ('OpenAI\n\nSam Altman', 1),
#  ('OpenAI ChatGPT', 1),
#  ('Proximal Policy Optimization', 1),
#  ('Microsoft', 1),
#  ('feedback.[10][11][12', 1),
#  ('December 30, 2022', 1),
#  ('Python', 1),
#  ('Christopher Columbus', 1),
#  ('US', 1),
#  ('U.S.', 1),
#  ('Goodhart', 1),
#  ('2021', 1),
#  ('BBC', 1),
#  ('two', 1),
#  ('November 30, 2022', 1),
#  ('2', 1),
#  ('Whisper', 1),
#  ('December 4', 1),
#  ('one million', 1),
#  ('CNBC', 1),
#  ('December 15, 2022', 1),
#  ('time".[27', 1),
#  ('English', 1),
#  ('Scott Aaronson', 1),
#  ('GPT', 1),
#  ('GPT-4', 1),
#  ('2023.[17', 1),
#  ('Positive', 1),
#  ('Guardian', 1),
#  ('Dan Gillmor', 1),
#  ('Alex Kantrowitz', 1),
#  ('Slate', 1),
#  ('Nazi Germany', 1),
#  ('Hitler', 1),
#  ('Germany', 1),
#  ("Nazi Germany's", 1),
#  ('Atlantic', 1),
#  ('Breakthroughs of the Year', 1),
#  ('2022', 1),
#  ('Derek Thompson', 1),
#  ('Vox', 1),
#  ('Paul Graham', 1),
#  ('Elon Musk', 1),
#  ('Twitter', 1),
#  ('2018.[39', 1),
#  ('Google', 1),
#  ('New York', 1),
#  ('January 3, 2023', 1),
#  ('Microsoft Bing', 1),
#  ('around March 2023.[41][42', 1),
#  ('Stuart Cobbe', 1),
#  ('England & Wales', 1),
#  ('ICAEW', 1),
#  ('42%', 1),
#  ('the 55%', 1)]

# %%
Counter(most_ent).most_common(10)
# Out:
# [('OpenAI', 11),
#  ('December 2022', 5),
#  ('AI', 4),
#  ('ChatGPT', 4),
#  ('2015', 3),
#  ('Columbus', 3),
#  ('San Francisco', 2),
#  ('first', 2),
#  ('InstructGPT', 2),
#  ('one', 2)]

# %%
print(len(doc1.ents))
# Out:
# 98

# %%
##MAtching

matcher_2=Matcher(nlp.vocab)
pattern_2=[{'text':'OpenAI'}]
matcher_2.add('Pattern2',[pattern_2])
match_2=matcher_2(doc1)

# %%
for match_id,start,end in match_2:
    span=doc1[start:end]
    print(span)
# Out:
# OpenAI
# OpenAI
# OpenAI
# OpenAI
# OpenAI
# OpenAI
# OpenAI
# OpenAI
# OpenAI
# OpenAI
# OpenAI
# OpenAI
# OpenAI

# %%
matcher_3=Matcher(nlp.vocab)
pattern_3=[{'LEMMA':'OpenAi'},
          {'LEMMA':' '}]


matcher_3.add('Pattern3',[pattern_3])
match_3=matcher_3(doc1)

# %%
for match_id,start,end in match_3:
    span=doc1[start:end]
    print(span)

# %%
matcher_4=Matcher(nlp.vocab)
pattern_4=[{'IS_ALPHA': True},
           {'IS_DIGIT':True}]

matcher_4.add('Pattern4',[pattern_4])
match_4=matcher_4(doc1)

# %%
for match_id,start,end in match_4:
    span=doc1[start:end]
    print(span)
# Out:
# December 30
# in 2015
# in 2015
# after 2021
# December 2022
# November 30
# December 4
# December 15
# December 2022
# December 2022
# December 2022
# for 2022
# in 2015
# December 2022
# January 3
# scored 42
# the 55

# %%
'''
pattern_3=[{'LEMMA':'language'}]
pattern_4=[{'IS_ALPHA': True},
           {'IS_DIGIT':True}]

pattern_5=[{'LEMMA':
            {'IN':['launch','discover','find',
        'invent','create','develop','innovate',
        'form','initiate']}}]
pattern_6=[{'LENGTH':{'>=':15}}]

pattern_7=[{'LENGTH':{'==':2}}]

pattern_10=[{"ENT_TYPE":'PERSON'}]
'''
# Out:
# '\npattern_3=[{\'LEMMA\':\'language\'}]\npattern_4=[{\'IS_ALPHA\': True},\n           {\'IS_DIGIT\':True}]\n\npattern_5=[{\'LEMMA\':\n            {\'IN\':[\'launch\',\'discover\',\'find\',\n        \'invent\',\'create\',\'develop\',\'innovate\',\n        \'form\',\'initiate\']}}]\npattern_6=[{\'LENGTH\':{\'>=\':15}}]\n\npattern_7=[{\'LENGTH\':{\'==\':2}}]\n\npattern_10=[{"ENT_TYPE":\'PERSON\'}]\n'

# %%
#bag of word

words_list=[]
for text in texts:
    doc=nlp(text)
    text_words=[]
    for token in doc:
        if token.is_stop==False and token.is_punct==False and token.like_num==False and token.text!='\n':
            text_words.append(token.lemma_)
    words_list.append(text_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [143], in <cell line: 4>()
#       1 #bag of word
#       3 words_list=[]
# ----> 4 for text in texts:
#       5     doc=nlp(text)
#       6     text_words=[]
#
# NameError: name 'texts' is not defined

# %%
print(len(words_list[1]))

# %%
corpus=[]
from gensim.corpora import Dictionary

# %%
dict=Dictionary(words_list)
type(dict)

# %%
for word in words_list:
    corpus.append(dict.doc2bow(word))

print(corpus)

# %%
#LDA

lda=gensim.models.ldamodel.LdaModel(corpus=corpus,
                                   num_topics=5,
                                   id2word=dict)

type(lda)

lda.print_topics()

lda.print_topics()[:2]

# %% [markdown]
# This section serves as a short reminder on what we are trying to do. CareerVillage, in its essence, is like Stackoverflow or Quora but for career questions. Users can post questions about any careers like computer science, pharmacology, aerospace engineering etc, and volunteer professionals try their best to answer the questions.
#
# When a new question comes in, CareerVillage recommends that question to a specific professional who is suitable to answer that question. In order to maximize the chance that a user’s questions get answered, CareerVillage needs to send the right question to the most apt professional. This is where our job comes in! We have to design a recommendation system that takes in a newly posted question, and outputs the professionals who are most suitable to answer that question.

# %%
lda.get_term_topics('game')

lda.get_term_topics('politics')

lda.get_term_topics('famous')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [144], in <cell line: 1>()
# ----> 1 lda.get_term_topics('game')
#       3 lda.get_term_topics('politics')
#       5 lda.get_term_topics('famous')
#
# NameError: name 'lda' is not defined

# %%
#VIzualisation

pyLDAvis.enable_notebook()


plot=pyLDAvis.gensim_models.prepare(lda,
                                    corpus=corpus,
                                   dictionary=lda.id2word)

plot

# %%
#Sentiment analysis

# %%
blob1=TextBlob(text1)

# We want to have the sentiment

blob1.sentiment

# %%
#TFIDF vectors

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf=TfidfVectorizer()

features=tf.fit_transform(data)

print(features)

# %%
#Clustering

#elbow
SSD=[]
for k in range(1,10):
    kmeans=KMeans(n_clusters=k, random_state=10)
    kmeans.fit(features)
    SSD.append(kmeans.inertia_)
plt.plot(range(1,10),SSD);


## Applying silhouette_score
from sklearn.metrics import silhouette_score
SS=[]
for k in range(2,11):
    kmeans=KMeans(n_clusters=k, random_state=10)
    kmeans.fit(features)
    SS.append(silhouette_score(features,kmeans.predict(features)))
    
plt.plot(range(2,11),SS);

# %%
kmeans=KMeans(n_clusters=5,random_state=10)
kmeans.fit(features)


kmeans.labels_

# %%
bbc['Cluster']=kmeans.labels_

#dimension reduction using TNSE

from sklearn.manifold import TSNE

tsne=TSNE(n_components=2,perplexity=30,random_state=10)

features_tsne=tsne.fit_transform(features)

features_tsne

features_tsne.shape

#vizualization

plt.figure(figsize=(10,8))
plt.scatter(features_tsne[:,0],features_tsne[:,1]);

plt.figure(figsize=(10,8))
plt.scatter(features_tsne[:,0],features_tsne[:,1],c=bbc['Cluster']);
